# %%
# %load_ext watermark
# %watermark -a mkjang -d -v
# Out:
# mkjang 2019-08-12
#
# CPython 3.7.3
# IPython 7.6.1

# %% [markdown]
# ============유해도 필터링 함수===========

# %%
import numpy as np
import pandas as pd
import json
import re


def AUTO_LABEL(dataset,dictionary):
    '''
    인풋으로 '비속어사전'(dictionary)과 '필터링할 DataFrame'을 사용합니다.
     
    그러면 이 함수는 해당 dataFrame과 비속어사전을 매핑하여, 
    비속어사전에 있는 단어가 해당파일에 있는 경우에
    필터링된 파일(dataset)에 유해함 여부를 1로써 나타냅니다.
    
    이때 유해도를 나타내는 컬럼은 dataset에서 새로운 'filtered'에 나타나며
    filtered는 디폴트로 0 값을 갖고 있다가, 비속어 사전과 채팅의 데이터가 매핑되면
    유해도가 1로 변경됩니다.
      
    '''
# 1. 데이터 셋 불러오기
    datasets = pd.DataFrame()
    dump = pd.read_csv(dataset, engine='python')
    datasets = pd.concat([datasets, dump])
        
# 2. 비속어 사전 불러오기
    with open(dictionary,'r') as f:
        forbiddenword = json.load(f)
        list2=list(forbiddenword.values()) 
        dict=list2[0] 
        dict1="|".join(dict) 
        
        
# 3. filtered라는 컬럼을 데이터셋에 추가함. (디폴트0, 필터되어 유해하면 1로 변경)
    datasets['filtered']=0
    data = datasets.comment

# 4. 유해 여부 실질적으로 판단
    idx = [i for i,d in enumerate(data) if re.search(dict1, d)]   
    datasets.iloc[idx,-1] = 1
    return datasets
#     return datasets[datasets['filtered']==1]
#=>필터된거만 보고싶을때

# %%
AUTO_LABEL('../../data/labeled (3).csv','word-fobidden.json')
# Out:
# ['jonna', 'mi쳤', '새끼', '개새', '쌉', '개간', '럼들', '시부럴', '시뷰럴', '씨부럴', '씨뷰럴', '시부렬', '시뷰렬', '씨부렬', '씨뷰렬', '쳐받는', '닝기리', '스벌', '호로잡', '개공감', '개나 소나', '개나소나', '개넷', '개년', '개념빠가', '개독', '개련', '개망', '개부랄', '개새기', '개새끼', '개 새끼', '죶', '개섹', '개셈', '개소리', '개쉽', '개싫', '개쎔', '개자식', '계새끼', '개저씨', '김치녀', '맘충', '엿같', '존낙', '젖 같', '졏 같', '닥치세', '에라이퉤', '에라이 퉤', '에라이퉷', '에라이 퉷', '슈벌', '슈우벌', '빻은', '빻았', '오진다', '오져', '골 빈', '골1빈', '골빈', '글러 먹', '글러먹', '오짐', '지들이', '관.종', '관1종', '관종', '괘새끼', '구1씹', '구씹', '그1켬', '그켬', '극1혐', '극혐', '기자레기', '까내리', '껒여', '꼬라지', '꼴갑', '꼴값', '꼴깝', 'ㄴ1ㅇㄱ', 'ㄴㅇ1ㄱ', 'ㄴㅇㄱ', '나면갤', '나빼썅', '남1연갤', '남1혐', '남ㅇㄱ', '남연1갤', '넌씨눈', '년놈', '노무노무', '년', '노알라', '노친네', '눈깔', '눈깔파', '늬믜', '늬미', '니년', '니믜', '니미럴', '애미', '앰', 'ㄷㅇㅂ', '닥1', '닥2', '덬', '대가리', '머갈', '대갈', '정병', '덜떨어', '도랏', '도랐', '시바알', '도른', ' 은새끼', '씨벌', '돌았나', '돌았네', '둄마', '뒈져', '뒤져야', '쓰레기새', '쓰레기', '씹뻐럴', '
�', '씹덕', '씹새끼', '씨빠빠', '사새끼', '씨바알', '씹창', '씹치', '씹팔', '씹할', 'ㅇㅍㅊㅌ', 'ㅇㅒ쁜', '아닥', '아오 시바', '아오시바', '안물안궁', '앰창', '얘쁘', '얘쁜', '얪', '엠뷩신', '엠븽신', '엠빙신', '엠생', '엠창', '엿이나', '예.질', '예1질', '예질', '옘병', '오크', '외1퀴', '외퀴', '은년', '젼나', '젼낰', '졀라', '졀리', '졌같은', '조낸', '조녜', '조온', '조온나', '족까', '중립충', '존 나', '존 나', '존', '존.나', '존1', '존1나', '존귀', '존귘', '존ㄴ나', '존쎄', '존쎼', '좁밥', '좃', '종나', '좆', '봊', 'jot같', '이 새끼', '젗같', '싸물어', '아가리', '닥쳐라', '씨버럼', '개쓰래기', '쓰래기같', '좆까', '좇', '죠낸', '죠온나', '죤나', '죤내', '죵나', '죽어버려', '줬같은', '같은새끼', '쥐랄', '씹쌔', '쥰나', '쥰니', '쥰트', '즤랄', '지 랄', '지1랄', '지뢰', '지1뢰', '지껄이', '지랄', '뚝딱', '삐걱', '지롤', 'ㅉ', '와꾸', 'ㅅㅌㅊ', 'ㅎㅌㅊ', 'ㅍㅌㅊ', '개삼성', '꼴데', '짱깨', '짱께', '쪼녜', '쪽1바리', '쪽바리', '쪽발', '쫀 맛', '쫀1', '쫀귀', '쫀맛', '쫂', '쫓같', '쬰잘', '쬲', '쯰질', '찌1질', '찍찍이', '찎찎이', '창년', '창놈', '凸', '첫빠', '쳐먹', '쳐발라', '취ㅈ', '취좃', '친 년', '친 놈', '친년', '친노마', '친놈', '텐귀', '텐덕', '톡디', '파1친', '파친', '피뎁', '피뎊', '피코', '피해자 코스프레', '피해자코스프레', '핑1프', '핑거프린세스', '핑프', 'ㅎㅃ', '할많하않', '할말하않', '헛소리', '혐석', '호로새끼', '새.끼', '화낭년', '화냥년', '후.려', '후1려', '후1빨', '후려', '후빨', '환멸', '환1멸']
#                                                 comment  url_id  label  \
# 50                                            미절앰! 미절앰!      15      0
# 54                  "cocoby0912" 회원님 폐드립건으로 징역2년형 고소합니다      36      1
# 135                                               독도 빼앰      56      0
# 258                            ㄴㅇㄱㄴㅇㄱㄴㅇㄱㄴㅇㄱㄴㅇㄱㄴㅇㄱㄴㅇㄱㄴㅇㄱ      51      0
# 354                                               브베애미노      38      1
# 359                                          아이유 쌉고인물인데      55      1
# 402                                       8910 도원결의 오지네      12      0
# 418           진짜 창석이형 스타듀벨리하는거 보면 암걸려 뒤져버릴꺼같으니까 제발 다른거해      35      1
# 420                                                ㅁㅊ놈들      11      1
# 437                                           2년전 그는...      12      0
# 479                                                꼴데..      72      0
# 644                                                 앰만튀      13      1
# 810                                                 쌉가능      55      1
# 849                                           위도우 좆사기챔프      28      1
# 976                                                  ㅁㅊ      12      1
# 980                                  애쉬 존야 뭐임? ㅋㅋㅋㅋㅋㅋㅋㅋ      11      0
# 991                                           ㅅㅂ 목소리 ㅋㅋ      20      1
# 1051                                               ㅇㅅㅂㅅ      17      0
# 1307                                             탱의 존심을      54      0
# 1427                                 훼이크 돌았나 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ      72      1
# 1675                                      쓰레기통 숨기가 되넼ㅋㅋ      56      0
# 1727                                             2년전만해도      56      0
# 1895                                     카이사 미쳤나 ㅋㅋㅋㅋㅋㅋ      16      0
# 1907                                                5년전      20      0
# 1960                                               쌉고인물      14      1
# 1987                                           병신진짜 ㅋㅋㅋ      34      1
# 1988                                캐년 베릴은 아무거나 상관없다는건가      16      0
# 2044                                 나쁜건형이지는 못들었나 멍청한가봐      37      0
# 2081                           낮혐석!낮혐석!낮혐석!낮혐석!낮혐석!낮혐석!      15      1
# 2101                아니 브베 씨발아 영어 좆도 못하면 DLC 사서 한국어로 하라고      40      1
# 2230                                               ㅇㅅㅂㅅ      15      0
# 2240                                       조건 미쳤나ㅋㅋㅋㅋㅋㅋ      76      1
# 2268                                                ㅁㅊㄷ      15      1
# 2286          진짜 창석이형 스타듀벨리하는거 보면 암걸려 뒤져버릴꺼같으니까 제발 다른거해      35      1
# 2296                                                앰빠따      18      1
# 2371                             3년 휴방으로 채운 체력 다 씀ㅋㅋㅋㅋㅋ      52      0
# 2401                                   프레이 박수칠때 떠났어야지 ㅉ      12      0
# 2458                                    닥쳐병신들아 브베는 신이니까      34      1
# 2459                                       젠지식존버를 킹존이하네      16      0
# 2501                                              ㅂㄹㅈㄷㅇ      18      0
# 2508  로리타 중독자새끼야 너 빨리 신원조회해서 범죄기록없는지 보여줘라 혜화중학생 3학년 ...      36      1
# 2520                                               탑 생존      16      0
# 2524                                         앰낳굌ㅋㅋㅋㅋㅋㅋㅋ      16      0
# 2559                                        팡머 그자체 앰비션;      16      0
# 2639                                     1-1에서 아이탬 나오져?      62      0
# 2643                                      리신까지 존야가면 레전드      11      0
# 2701                      아 내일 군대 ㅅㅂ 브베 욕듣는거 한동안 못보내 ㅜㅜ      37      1
# 2703                                       손거울 스노우볼 오졌다      51      0
# 2739                                               디질라고      34      1
# 2775                                    정 글 절 대 자 앰 비 션      16      0
# 2791                                  이년ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ      57      1
# 2843                    겟엠 2년 롤백 된 뒤 템 뿌려줘서 더 좋아졌다고 하던데      70      0
# 2866          진짜 창석이형 스타듀벨리하는거 보면 암걸려 뒤져버릴꺼같으니까 제발 다른거해      35      1
# 2899                                           짬처리 오지고       34      1
# 2919                                         정신공격오진다 ㅋㅋ      77      0
# 2940                                   안해줘 ㅋㅋㅋㅋ 쓰레기같은 넘      31      1
# 2956                                          ㅇㅅㅂㅅ!~!!!      18      0
# 2979                  바쁘대 병신ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ      34      1
#
#       filtered
# 50           1
# 54           1
# 135          1
# 258          1
# 354          1
# 359          1
# 402          1
# 418          1
# 420          1
# 437          1
# 479          1
# 644          1
# 810          1
# 849          1
# 976          1
# 980          1
# 991          1
# 1051         1
# 1307         1
# 1427         1
# 1675         1
# 1727         1
# 1895         1
# 1907         1
# 1960         1
# 1987         1
# 1988         1
# 2044         1
# 2081         1
# 2101         1
# 2230         1
# 2240         1
# 2268         1
# 2286         1
# 2296         1
# 2371         1
# 2401         1
# 2458         1
# 2459         1
# 2501         1
# 2508         1
# 2520         1
# 2524         1
# 2559         1
# 2639         1
# 2643         1
# 2701         1
# 2703         1
# 2739         1
# 2775         1
# 2791         1
# 2843         1
# 2866         1
# 2899         1
# 2919         1
# 2940         1
# 2956         1
# 2979         1
