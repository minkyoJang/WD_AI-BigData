# %%
from bs4 import BeautifulSoup
import requests
import time
import re
import lxml

# %%
def download(method, url, header=None, param=None, data=None, timeout=1, maxretries=3):
    try:
        resp = requests.request(method, url, headers=header, params=param, data=data)
        resp.raise_for_status()
    except requests.exceptions.HTTPError as e:
        if 500 <= e.response.status_code < 600 and maxretries>0:
            time.sleep(timeout)
            print('시도 {}'.format(maxretries))
            download(method, url, header, param, data, timeout, maxretries-1)
        else:
            print(e.response.status_code)
            print(e.response.reason)
    return resp

# %%
url = "http://afevent2.afreecatv.com/app/rank/api.php"
param = {
    "swWhich" : "favorite", "nPage":1, "szGender":"A"
}
header = {"개인 유저에이전트 작성"}
html = download("post", url, param=param, header=header)
dom = BeautifulSoup(html.text, "lxml")

# %%
bj_list=[]

for i in range(34069):
    i = i+1
    url = "http://afevent2.afreecatv.com/app/rank/api.php"
    param = {
        "swWhich" : "favorite", "nPage":i, "szGender":"A"}
    header = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36"}
    html = download("post", url, param=param, header=header)
    dom = BeautifulSoup(html.text, "lxml")
    bj_list.append([(_['bj_id'], _["bj_nick"]) for _ in html.json()['ALL_RANK']])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-36739a5f849f> in <module>
#       7         "swWhich" : "favorite", "nPage":i, "szGender":"A"}
#       8     header = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36"}
# ----> 9     html = download("post", url, param=param, header=header)
#      10     dom = BeautifulSoup(html.text, "lxml")
#      11     bj_list.append([(_['bj_id'], _["bj_nick"]) for _ in html.json()['ALL_RANK']])
#
# <ipython-input-2-701acffc605d> in download(method, url, header, param, data, timeout, maxretries)
#       1 def download(method, url, header=None, param=None, data=None, timeout=1, maxretries=3):
#       2     try:
# ----> 3         resp = requests.request(method, url, headers=header, params=param, data=data)
# ...

# %%
len(bj_list)
# Out:
# 399

# %%
afre_bj_list=[]
for i in range(34069):
    i = i+1
    url = "http://afevent2.afreecatv.com/app/rank/api.php"
    param = {
        "swWhich" : "favorite", "nPage":i, "szGender":"A"}
    header = {"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.100 Safari/537.36"}
    html = download("post", url, param=param, header=header)
    dom = BeautifulSoup(html.text, "lxml")
    afre_bj_list.append([(_['bj_id'], _["bj_nick"]) for _ in html.json()['ALL_RANK']])

# %%
test_bj_list
# Out:
# [[('rlaxordyd', 'Bisu김택용'),
#   ('rrvv17', '항상#킴성태'),
#   ('dlghfjs', '깨박이깨박이'),
#   ('wnnw', '[NS남순]'),
#   ('lshooooo', 'BJ이상호'),
#   ('coqhal1992', '채보미=3'),
#   ('eunz1nara', '양팡♥'),
#   ('khm11903', '와꾸대장봉준'),
#   ('tsoul7', '노래하는코트'),
#   ('ss7169', 'BJ쯔양'),
#   ('toos12', 'BJ차돈'),
#   ('seokwngud', '뜨뜨뜨뜨-'),
#   ('barams01', '대세는BJ세야'),
#   ('yunheehoho', 'BJ서윤♥:)'),
#   ('e9dongsung', '이스타이주헌'),
#   ('kimdhun', '킹기훈'),
#   ('b13246', 'BJ타요'),
#   ('ch1716', '예능인[최군]'),
#   ('freetouch21c', '꿀보스정진우'),
#   ('pookygamja', '[BJ]김인호'),
#   ('rlatldgus', '오메킴승현2'),
#   ('suhee0051', '수힛'),
#   ('partypeople', '최고다윽박'),
#   ('kogo0512', '수탉'),
#   ('byflash', 'FlaSh.이영호'),
#   ('gtv7', '*망치부인*'),
#   ('arinbbidol', '기뉴다'),
#   ('llilka', '릴카♥'),
#   ('phonics1', '김민교.'),
#   ('ioioiobb', 'BJ정윤종'),
#   ('dpfgc3', '액션홍구'),
#   ('melody0725', '손밍'),
#   ('lolsos', '#미래:3'),
#   ('m0m099', '세연겸둥'),
#   ('dasl8121', '♥이슬이'),
#   ('yoobee22', 'BJ지효♡'),
#   ('joey1114', '저라뎃'),
# ...

# %%
len(bj_list)
# Out:
# 18632

# %%
len(afre_bj_list)
# Out:
# 34069

# %%
afre_bj_list
# Out:
# [[('rlaxordyd', 'Bisu김택용'),
#   ('rrvv17', '항상#킴성태'),
#   ('dlghfjs', '깨박이깨박이'),
#   ('wnnw', '[NS남순]'),
#   ('lshooooo', 'BJ이상호'),
#   ('coqhal1992', '채보미=3'),
#   ('eunz1nara', '양팡♥'),
#   ('khm11903', '와꾸대장봉준'),
#   ('tsoul7', '노래하는코트'),
#   ('ss7169', 'BJ쯔양'),
#   ('toos12', 'BJ차돈'),
#   ('seokwngud', '뜨뜨뜨뜨-'),
#   ('barams01', '대세는BJ세야'),
#   ('yunheehoho', 'BJ서윤♥:)'),
#   ('e9dongsung', '이스타이주헌'),
#   ('kimdhun', '킹기훈'),
#   ('b13246', 'BJ타요'),
#   ('ch1716', '예능인[최군]'),
#   ('freetouch21c', '꿀보스정진우'),
#   ('pookygamja', '[BJ]김인호'),
#   ('rlatldgus', '오메킴승현2'),
#   ('suhee0051', '수힛'),
#   ('partypeople', '최고다윽박'),
#   ('kogo0512', '수탉'),
#   ('byflash', 'FlaSh.이영호'),
#   ('gtv7', '*망치부인*'),
#   ('arinbbidol', '기뉴다'),
#   ('llilka', '릴카♥'),
#   ('phonics1', '김민교.'),
#   ('ioioiobb', 'BJ정윤종'),
#   ('dpfgc3', '액션홍구'),
#   ('melody0725', '손밍'),
#   ('lolsos', '#미래:3'),
#   ('m0m099', '세연겸둥'),
#   ('dasl8121', '♥이슬이'),
#   ('yoobee22', 'BJ지효♡'),
#   ('joey1114', '저라뎃'),
# ...

# %%
import pickle

# %%
with open('af2ca_bj_list.csv','wb') as f:
    pickle.dump(afre_bj_list,f)

# %%
with open('af2ca_bj_list.csv','rb') as f:
    data= pickle.load(f)

# %%
data
# Out:
# [[('rlaxordyd', 'Bisu김택용'),
#   ('rrvv17', '항상#킴성태'),
#   ('dlghfjs', '깨박이깨박이'),
#   ('wnnw', '[NS남순]'),
#   ('lshooooo', 'BJ이상호'),
#   ('coqhal1992', '채보미=3'),
#   ('eunz1nara', '양팡♥'),
#   ('khm11903', '와꾸대장봉준'),
#   ('tsoul7', '노래하는코트'),
#   ('ss7169', 'BJ쯔양'),
#   ('toos12', 'BJ차돈'),
#   ('seokwngud', '뜨뜨뜨뜨-'),
#   ('barams01', '대세는BJ세야'),
#   ('yunheehoho', 'BJ서윤♥:)'),
#   ('e9dongsung', '이스타이주헌'),
#   ('kimdhun', '킹기훈'),
#   ('b13246', 'BJ타요'),
#   ('ch1716', '예능인[최군]'),
#   ('freetouch21c', '꿀보스정진우'),
#   ('pookygamja', '[BJ]김인호'),
#   ('rlatldgus', '오메킴승현2'),
#   ('suhee0051', '수힛'),
#   ('partypeople', '최고다윽박'),
#   ('kogo0512', '수탉'),
#   ('byflash', 'FlaSh.이영호'),
#   ('gtv7', '*망치부인*'),
#   ('arinbbidol', '기뉴다'),
#   ('llilka', '릴카♥'),
#   ('phonics1', '김민교.'),
#   ('ioioiobb', 'BJ정윤종'),
#   ('dpfgc3', '액션홍구'),
#   ('melody0725', '손밍'),
#   ('lolsos', '#미래:3'),
#   ('m0m099', '세연겸둥'),
#   ('dasl8121', '♥이슬이'),
#   ('yoobee22', 'BJ지효♡'),
#   ('joey1114', '저라뎃'),
# ...
