# %%
import sqlite3
con = sqlite3.connect("youtube.db")
cur = con.cursor()

# %%
cur.executescript('''
    CREATE TABLE url(
    id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
    netloc_id INTEGER NOT NULL,
    path TEXT NOT NULL,
    param TEXT,
    bj_id INTEGER NOT NULL,
    title TEXT NOT NULL
    );

    CREATE TABLE netloc(
    id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
    netloc TEXT NOT NULL
    );

    CREATE TABLE chat(
    id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
    content TEXT NOT NULL,
    writer_id INTEGER NOT NULL,
    w_time TEXT NOT NULL, 
    url_id INTEGER NOT NULL
    );

    CREATE TABLE jamak(
    id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
    content TEXT NOT NULL,
    j_time TEXT NOT NULL,
    url_id INTEGER NOT NULL
    );

    CREATE TABLE bj(
    id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
    name TEXT NOT NULL,
    netloc_id INTEGER NOT NULL
    );

    CREATE TABLE writer(
    id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
    name TEXT NOT NULL
    );
    
    ''')

con.commit()

# %%
import requests
from urllib import error
import time

# 본인의 headers를 user-agent에 사용
headers = {"user-agent": }

def download(method, url, param=None, data=None, timeout=1, maxretries=3):
    try:
        resp = requests.request(method, url, params=param, data=data, headers=headers)
        resp.raise_for_status()
    except requests.exceptions.HTTPError as e:
        if 500 <= e.response.status_code < 600 and maxretries > 0:  
            print(maxretries)                                       
            time.sleep(timeout)                                     
            resp = download(method, url, param, data, timeout, maxretries-1)
            print("재시도")
        else:
            print(e.response.status_code)
            print(e.response.reason)
    return resp

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import json
import time
import os
import re
import random
from urllib3.exceptions import MaxRetryError

def youtube(n = 8, seed = 'https://www.youtube.com/watch?v=9FZTL-MH6Sk&app=desktop'):

    netloc = "www.youtube.com"
    path = ["/watch"]
    param = [] 
    seed_list = []
    bj = []
    title = []
    temp_path_param = []
    temp_param = "&app=desktop"
    p = re.compile("[0-9\:\,]+\\n[ㄱ-ㅎㅏ-ㅣ가-힣0-9\,\'A-Za-z\s]+[ㄱ-ㅎㅏ-ㅣ가-힣]")
    text_temp = []
    path_temp = '/Users/user/Downloads/'
    driver = webdriver.Chrome()
    q = -1
    break_key = 0
    sub_index = 0
    
    param.append('?' + seed.split('/')[3].split('?')[1]) # 시작 seed 주소의 parameter
    
    for c in range(n):
        i = c - sub_index
        print(i)
        break_key = 0
        
        html = download("get", seed)
        dom = BeautifulSoup(html.text, "lxml")
        
        print("seed : " + seed)
        url = seed
        seed_list.append(seed)
        
        try:
            bj.append([_.text for _ in dom.select("div.yt-user-info > a")][0])
            title.append([_.text for _ in dom.select("#eow-title")][0])
        
        except IndexError: # 영상이 차단된 경우
            break_key = 1
            seed = seed_list[-2]
            sub_index += 2
            continue
        
        temp_path_param.append([_['href'] for _ in dom.select(".content-link.spf-link.yt-uix-sessionlink.spf-link")][random.randint(0,3)])
        
        path.append(temp_path_param[i].split("?")[0])
        param.append("?" + temp_path_param[i].split("?")[1] + temp_param)
        
        seed = "https://" + netloc + path[i+1] + param[i+1]
        
        cur.execute("SELECT id FROM url WHERE param=? LIMIT 0,1", [param[i]])
        temp_param_exist = cur.fetchone()
        
        if temp_param_exist:
            continue
        
        driver.get("https://savesubs.com/")
        driver.find_element_by_css_selector(".search_wrap > div").click()
        driver.find_element_by_name("url").send_keys(url)
        driver.find_element_by_css_selector(".search_wrap > input").click()
        time.sleep(15)
        try:
            for k in driver.find_elements_by_css_selector(".list-reset > li"):
                if (k.find_elements_by_css_selector("span")[0].text == "SRT") & ((k.find_elements_by_css_selector("span")[1].text == "KOREAN (AUTO-GENERATED)") | (k.find_elements_by_css_selector("span")[1].text == "KOREAN")):
                    k.find_element_by_css_selector("a").click()
                    break
            else:
                break_key = 1
                
        except IndexError: # 자막이 없는 경우
            break_key = 1
            continue
        
        if break_key:
            time.sleep(5)
            continue
        
        time.sleep(15)
        
        q += 1
        
        cur.execute("SELECT id FROM netloc WHERE netloc=? LIMIT 0,1", [netloc])
        netloc_exist = cur.fetchone()
        
        if not netloc_exist:
            cur.execute("INSERT INTO netloc(netloc) VALUES(?)", [netloc])
            con.commit()
            
            cur.execute("SELECT id FROM netloc WHERE netloc=? LIMIT 0,1", [netloc])
            netloc_exist = cur.fetchone()
        
        cur.execute("SELECT id FROM bj WHERE name=? LIMIT 0,1", [bj[i]])
        bj_exist = cur.fetchone()
        
        if not bj_exist:
            cur.execute("INSERT INTO bj(name, netloc_id) VALUES(?, ?)", [bj[i], netloc_exist[0]])
            con.commit()
                         
            cur.execute("SELECT id FROM bj WHERE name=? LIMIT 0,1", [bj[i]])
            bj_exist = cur.fetchone()
                                    
        cur.execute("SELECT id FROM url WHERE param=? LIMIT 0,1", [param[i]])
        param_exist = cur.fetchone()
        
        if not param_exist:
            cur.execute("INSERT INTO url(netloc_id, path, param, bj_id, title) VALUES(?, ?, ?, ?, ?)", 
                        [netloc_exist[0], path[i], param[i], bj_exist[0], title[i]])
            con.commit()
            
            print(title[i])
            
            cur.execute("SELECT id FROM url WHERE param=? LIMIT 0,1", [param[i]])
            param_exist = cur.fetchone()
                         
        temp = []

        for r, d, f in os.walk('/Users/user/Downloads/'):
            temp.append(f)
            # 파일을 다운로드 받는 default 경로가 /Users/user/Downloads/ 이고, 
            # Downloads 폴더 안에 어떠한 파일도 없어야 함
        
        print(temp)
        if temp[0][1] == "desktop.ini":
            filepath = path_temp + temp[0][0]
        else:
            filepath = path_temp + temp[0][1]
        print(filepath)
        f = open(filepath, encoding='UTF8')
        text = p.findall(f.read())
        f.close()
        os.remove(filepath)
        text_temp.append(text)
    
        temp1 = []
        temp2 = []

        for _ in text_temp[q]:
            temp1.extend(re.findall(r'(.+?),\d\d\d\n(.+)',_) )
        temp2.append(temp1)
        temp1 = []
        
        for x in range(len(temp2[0])):
            cur.execute("INSERT INTO jamak(content, j_time, url_id) VALUES(?, ?, ?)", 
                        [temp2[0][x][1], temp2[0][x][0], param_exist[0]])
            con.commit()

# %%
youtube(n = 500, seed = "https://www.youtube.com/watch?v=xUVM-8gvj-Q&app=desktop") # seed = 철구

# seed 주소에 &app=desktop 을 넣어주지 않으면 모바일 버전으로 바뀜

# "https://www.youtube.com/watch?v=8eSH6ZLsi6I&app=desktop" -> 차단된 영상
# Out:
# 0
# seed : https://www.youtube.com/watch?v=xUVM-8gvj-Q&app=desktop
#
#     세계최초 택배로 X을 받았습니다...
#
# [['desktop.ini', '세계최초 택배로 X을 받았습니다... - Korean (auto-generated).srt']]
# /Users/user/Downloads/세계최초 택배로 X을 받았습니다... - Korean (auto-generated).srt
# 1
# seed : https://www.youtube.com/watch?v=cwCFsHHNvOg&app=desktop
#
#     [합방#3] [철구냄새캐리!] 내 남자의 발,배꼽,겨드랑이,정수리,입냄새 맞춰라....그리고 토하러 뛰쳐나간다?ㅣ용느x철구x기훈x지혜x가현x따규x햅번 2018.01.13
#
# [['desktop.ini', '[합방#3] [철구냄새캐리!] 내 남자의 발,배꼽,겨드랑이,정수리,입냄새 맞춰라....그리고 토하러 뛰쳐나간다_ㅣ용느x철구x기훈x지혜x가현x따규x햅번 2018.01.13 - Korean (auto-generated).srt']]
# /Users/user/Downloads/[합방#3] [철구냄새캐리!] 내 남자의 발,배꼽,겨드랑이,정수리,입냄새 맞춰라....그리고 토하러 뛰쳐나간다_ㅣ용느x철구x기훈x지혜x가현x따규x햅번 2018.01.13 - Korean (auto-generated).srt
# 2
# seed : https://www.youtube.com/watch?v=HDYZcGqwbNg&app=desktop
#
#     한국 유튜버가 일본전을 하면 생기는일 [배틀그라운드]
#
# [['desktop.ini', '한국 유튜버가 일본전을 하면 생기는일 [배틀그라운드] - Korean (auto-generated).srt']]
# /Users/user/Downloads/한국 유튜버가 일본전을 하면 생기는일 [배틀그라운드] - Korean (auto-generated).srt
# 3
# seed : https://www.youtube.com/watch?v=2w6Xy4njbkw&app=desktop
#
#     상위 0.06퍼의 실력자를 만났습니다. 근데 익숙한 목소리가?! 【랜덤스쿼드】 [배틀그라운드]
#
# [['desktop.ini', '상위 0.06퍼의 실력자를 만났습니다. 근데 익숙한 목소리가_! 【랜덤스쿼드】 [배틀그라운드] - Korean (auto-generated).srt']]
# /Users/user/Downloads/상위 0.06퍼의 실력자를 만났습니다. 근데 익숙한 목소리가_! 【랜덤스쿼드】 [배틀그라운드] - Korean (auto-generated).srt
# 4
# seed : https://www.youtube.com/watch?v=E7NNmXUyJuA&app=desktop
#
#     홀로150명을 저격한 최고의 스나이퍼를 만나 고립된 군인
#
# [['desktop.ini', '홀로150명을 저격한 최고의 스나이퍼를 만나 고립된 군인 - Korean (auto-generated).srt']]
# /Users/user/Downloads/홀로150명을 저격한 최고의 스나이퍼를 만나 고립된 군인 - Korean (auto-generated).srt
# 5
# seed : https://www.youtube.com/watch?v=6DHdozBPrB4&app=desktop
#
#     세계에서 가장 미친 12개의 총알
#
# [['desktop.ini', '세계에서 가장 미친 12개의 총알 - Korean (auto-generated).srt']]
# /Users/user/Downloads/세계에서 가장 미친 12개의 총알 - Korean (auto-generated).srt
# 6
# seed : https://www.youtube.com/watch?v=irhFYBRQ3ds&app=desktop
#
#     20번의 대단한 역대 총 기록들
#
# [['20번의 대단한 역대 총 기록들 - Korean (auto-generated).srt', 'desktop.ini']]
# /Users/user/Downloads/20번의 대단한 역대 총 기록들 - Korean (auto-generated).srt
# 7
# seed : https://www.youtube.com/watch?v=6DHdozBPrB4&app=desktop
# 8
# seed : https://www.youtube.com/watch?v=6HcLm0QPOaM&app=desktop
#
#     역대 최고로 가장 위험하고, 강력한 7개의 저격용 소총
#
# [['desktop.ini', '역대 최고로 가장 위험하고, 강력한 7개의 저격용 소총 - Korean (auto-generated).srt']]
# /Users/user/Downloads/역대 최고로 가장 위험하고, 강력한 7개의 저격용 소총 - Korean (auto-generated).srt
# 9
# seed : https://www.youtube.com/watch?v=desDNreofUI&app=desktop
# 10
# seed : https://www.youtube.com/watch?v=E2xTtp10nHU&app=desktop
# 11
# seed : https://www.youtube.com/watch?v=FPnHU2y6w_A&app=desktop
#
#     스포츠계에서 가장 체격이 컸던 싸움
#
# [['desktop.ini', '스포츠계에서 가장 체격이 컸던 싸움 - Korean (auto-generated).srt']]
# /Users/user/Downloads/스포츠계에서 가장 체격이 컸던 싸움 - Korean (auto-generated).srt
# 12
# seed : https://www.youtube.com/watch?v=H7v1v1IVgSg&app=desktop
#
#     10 : 1 이 가능했던 중국 최고의 무술가
#
# [['10 _ 1 이 가능했던 중국 최고의 무술가 - Korean (auto-generated).srt', 'desktop.ini']]
# /Users/user/Downloads/10 _ 1 이 가능했던 중국 최고의 무술가 - Korean (auto-generated).srt
# 13
# seed : https://www.youtube.com/watch?v=a0OuYkmlUAA&app=desktop
#
#     문제아들의 학교에 미 특수부대 출신 선생님이 왔다 / 영화결말리뷰댓글 / 빅브라더
#
# [['desktop.ini', '문제아들의 학교에 미 특수부대 출신 선생님이 왔다 _ 영화결말리뷰댓글 _ 빅브라더 - Korean (auto-generated).srt']]
# /Users/user/Downloads/문제아들의 학교에 미 특수부대 출신 선생님이 왔다 _ 영화결말리뷰댓글 _ 빅브라더 - Korean (auto-generated).srt
# 14
# seed : https://www.youtube.com/watch?v=TcOcrXkijoM&app=desktop
#
#     천재소녀가 일반 학교를 가면 생기는 일
#
# [['desktop.ini', '천재소녀가 일반 학교를 가면 생기는 일 - Korean (auto-generated).srt']]
# /Users/user/Downloads/천재소녀가 일반 학교를 가면 생기는 일 - Korean (auto-generated).srt
# 15
# seed : https://www.youtube.com/watch?v=vEq8umfrgT0&app=desktop
#
#     9살 자폐아 미국의 1급 보안코드를 깼다!
#
# [['9살 자폐아 미국의 1급 보안코드를 깼다! - Korean (auto-generated).srt', 'desktop.ini']]
# /Users/user/Downloads/9살 자폐아 미국의 1급 보안코드를 깼다! - Korean (auto-generated).srt
# 16
# seed : https://www.youtube.com/watch?v=TcOcrXkijoM&app=desktop
# 17
# seed : https://www.youtube.com/watch?v=vEq8umfrgT0&app=desktop
# 18
# seed : https://www.youtube.com/watch?v=qmXpzTXBUPA&app=desktop
#
#     감옥생활 후 선생이 된 남자의 끝내주는 교육법
#
# [['desktop.ini', '감옥생활 후 선생이 된 남자의 끝내주는 교육법 - Korean (auto-generated).srt']]
# /Users/user/Downloads/감옥생활 후 선생이 된 남자의 끝내주는 교육법 - Korean (auto-generated).srt
# 19
# seed : https://www.youtube.com/watch?v=_ulg-pjJSGw&app=desktop
#
#     불사의 힘을 가지고 하늘에서 떨어진 여자
#
# [['desktop.ini', '불사의 힘을 가지고 하늘에서 떨어진 여자 - Korean (auto-generated).srt']]
# /Users/user/Downloads/불사의 힘을 가지고 하늘에서 떨어진 여자 - Korean (auto-generated).srt
# 20
# seed : https://www.youtube.com/watch?v=bfNDwWwa2TQ&app=desktop
#
#     강제로 '마녀'를 탐한 두 남자, 그 후 벌어진 일은…
#
# [['desktop.ini', "강제로 '마녀'를 탐한 두 남자, 그 후 벌어진 일은… - Korean (auto-generated).srt"]]
# /Users/user/Downloads/강제로 '마녀'를 탐한 두 남자, 그 후 벌어진 일은… - Korean (auto-generated).srt
# 21
# seed : https://www.youtube.com/watch?v=h184NgnkYfo&app=desktop
#
#     [사건스토리텔링] 불륜 남녀가 17년 간직한 비밀은?
#
# [['desktop.ini', '[사건스토리텔링] 불륜 남녀가 17년 간직한 비밀은_ - Korean (auto-generated).srt']]
# /Users/user/Downloads/[사건스토리텔링] 불륜 남녀가 17년 간직한 비밀은_ - Korean (auto-generated).srt
# 22
# seed : https://www.youtube.com/watch?v=pF2R8zOsoj8&app=desktop
#
#     [스카보로 레이피스트] 캐나다 역사상 가장 음흉하고 추악한 희대의 악마 커플
#
# [['desktop.ini', '[스카보로 레이피스트] 캐나다 역사상 가장 음흉하고 추악한 희대의 악마 커플 - Korean (auto-generated).srt']]
# /Users/user/Downloads/[스카보로 레이피스트] 캐나다 역사상 가장 음흉하고 추악한 희대의 악마 커플 - Korean (auto-generated).srt
# 23
# seed : https://www.youtube.com/watch?v=MzD2R2YElcE&app=desktop
# 24
# seed : https://www.youtube.com/watch?v=Q-qK2veEbss&app=desktop
# 25
# seed : https://www.youtube.com/watch?v=R5VqCMli6DY&app=desktop
# 26
# seed : https://www.youtube.com/watch?v=HVSQzc95f7I&app=desktop
# 27
# seed : https://www.youtube.com/watch?v=kzczvnkpYCI&app=desktop
#
#     아베의 굴욕...일본이 자랑하는 무기,  해외선 안팔리는 이유
#
# [['desktop.ini', '아베의 굴욕...일본이 자랑하는 무기, 해외선 안팔리는 이유 - Korean (auto-generated).srt']]
# /Users/user/Downloads/아베의 굴욕...일본이 자랑하는 무기, 해외선 안팔리는 이유 - Korean (auto-generated).srt
# 28
# seed : https://www.youtube.com/watch?v=_9snEQc86sA&app=desktop
#
#     일본수출규제 자국 침몰 앞당겨, (아베)'우리 안망했다고 말해줘'
#
# [['desktop.ini', "일본수출규제 자국 침몰 앞당겨, (아베)'우리 안망했다고 말해줘' - Korean.srt"]]
# /Users/user/Downloads/일본수출규제 자국 침몰 앞당겨, (아베)'우리 안망했다고 말해줘' - Korean.srt
# 29
# seed : https://www.youtube.com/watch?v=xjrE4-3N_3U&app=desktop
#
#     애플 요청 거절한 5G 칩 생산 늘린다! 삼성 이재용 승부수 던졌다! 퀄컴 아성 무너뜨린다!
#
# [['desktop.ini', '애플 요청 거절한 5G 칩 생산 늘린다! 삼성 이재용 승부수 던졌다! 퀄컴 아성 무너뜨린다! - Korean.srt']]
# /Users/user/Downloads/애플 요청 거절한 5G 칩 생산 늘린다! 삼성 이재용 승부수 던졌다! 퀄컴 아성 무너뜨린다! - Korean.srt
# 30
# seed : https://www.youtube.com/watch?v=KWc_MS6eTVs&app=desktop
#
#     긴급속보! 일본 수출제재 사실상 철회?  경제산업성 한일 기업끼리 협의되고 군사용도 전용 없으면 수출 허용! 그래놓고 후지 TV는 문재인 대통령 탄핵 언급
#
# [['desktop.ini', '긴급속보! 일본 수출제재 사실상 철회_ 경제산업성 한일 기업끼리 협의되고 군사용도 전용 없으면 수출 허용! 그래놓고 후지 TV는 문재인 대통령 탄핵 언급 - Korean.srt']]
# /Users/user/Downloads/긴급속보! 일본 수출제재 사실상 철회_ 경제산업성 한일 기업끼리 협의되고 군사용도 전용 없으면 수출 허용! 그래놓고 후지 TV는 문재인 대통령 탄핵 언급 - Korean.srt
# 31
# seed : https://www.youtube.com/watch?v=mqkop9KND3A&app=desktop
#
#     삼성을 긴급 방문한 미국 IT 공룡 아마존, 구글, 애플 그 이유가 뭘까? 삼성 비상태세 계속 유지한다! 협력사에 90일분 물량 확보 요청했다!
#
# [['desktop.ini', '삼성을 긴급 방문한 미국 IT 공룡 아마존, 구글, 애플 그 이유가 뭘까_ 삼성 비상태세 계속 유지한다! 협력사에 90일분 물량 확보 요청했다! - Korean.srt']]
# /Users/user/Downloads/삼성을 긴급 방문한 미국 IT 공룡 아마존, 구글, 애플 그 이유가 뭘까_ 삼성 비상태세 계속 유지한다! 협력사에 90일분 물량 확보 요청했다! - Korean.srt
# 32
# seed : https://www.youtube.com/watch?v=TdkmSLGvExs&app=desktop
#
#     삼성을 살리고 이나라 경제를 살리기 위해 폐지해야할 50가지의 정책들! -허경영-
#
# [['desktop.ini', '삼성을 살리고 이나라 경제를 살리기 위해 폐지해야할 50가지의 정책들! -허경영- - Korean (auto-generated).srt']]
# /Users/user/Downloads/삼성을 살리고 이나라 경제를 살리기 위해 폐지해야할 50가지의 정책들! -허경영- - Korean (auto-generated).srt
# 33
# seed : https://www.youtube.com/watch?v=bh0y73sYyB4&app=desktop
# 34
# seed : https://www.youtube.com/watch?v=hpmIFxBg5GA&app=desktop
#
#     ▶허경영의 다시 보는 대선 토론
#
# [['desktop.ini', '▶허경영의 다시 보는 대선 토론 - Korean (auto-generated).srt']]
# /Users/user/Downloads/▶허경영의 다시 보는 대선 토론 - Korean (auto-generated).srt
# 35
# seed : https://www.youtube.com/watch?v=ouZjYHBKtS4&app=desktop
# 36
# seed : https://www.youtube.com/watch?v=ekZ9z899xls&app=desktop
#
#     박정희 대통령 독일에 차관 빌리던 일화 (허경영)
#
# [['desktop.ini', '박정희 대통령 독일에 차관 빌리던 일화 (허경영) - Korean (auto-generated).srt']]
# /Users/user/Downloads/박정희 대통령 독일에 차관 빌리던 일화 (허경영) - Korean (auto-generated).srt
# 37
# seed : https://www.youtube.com/watch?v=vUNsxMNHijw&app=desktop
#
#     [팩트체크]허경영 총재는 원래 삼성家 이다!?(허본좌의 이병철 회장 양아들 썰 EP-02)
#
# [['desktop.ini', '[팩트체크]허경영 총재는 원래 삼성家 이다!_(허본좌의 이병철 회장 양아들 썰 EP-02) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[팩트체크]허경영 총재는 원래 삼성家 이다!_(허본좌의 이병철 회장 양아들 썰 EP-02) - Korean (auto-generated).srt
# 38
# seed : https://www.youtube.com/watch?v=q80-W-dScbA&app=desktop
# 39
# seed : https://www.youtube.com/watch?v=WHERMqnfNW4&app=desktop
#
#     허경영의 돈의 출처를 추적한 ‘탐사보도 세븐’팀! [탐사보도 세븐 17회] 20171213
#
# [['desktop.ini', '허경영의 돈의 출처를 추적한 ‘탐사보도 세븐’팀! [탐사보도 세븐 17회] 20171213 - Korean (auto-generated).srt']]
# /Users/user/Downloads/허경영의 돈의 출처를 추적한 ‘탐사보도 세븐’팀! [탐사보도 세븐 17회] 20171213 - Korean (auto-generated).srt
# 40
# seed : https://www.youtube.com/watch?v=1W9L-i5FDNg&app=desktop
#
#     롤스로이스를 신차로 구매하면 트렁크에 뭐가 들어있을까요?
#
# [['desktop.ini', '롤스로이스를 신차로 구매하면 트렁크에 뭐가 들어있을까요_ - Korean (auto-generated).srt']]
# /Users/user/Downloads/롤스로이스를 신차로 구매하면 트렁크에 뭐가 들어있을까요_ - Korean (auto-generated).srt
# 41
# seed : https://www.youtube.com/watch?v=6CrtKcQkhA4&app=desktop
#
#     김재경 대표와 함께하는 7억 롤스로이스 팬텀과 4억 고스트의 차이점, Feat S650 Maybach
#
# [['desktop.ini', '김재경 대표와 함께하는 7억 롤스로이스 팬텀과 4억 고스트의 차이점, Feat S650 Maybach - Korean (auto-generated).srt']]
# /Users/user/Downloads/김재경 대표와 함께하는 7억 롤스로이스 팬텀과 4억 고스트의 차이점, Feat S650 Maybach - Korean (auto-generated).srt
# 42
# seed : https://www.youtube.com/watch?v=jCK2EYWFVWc&app=desktop
#
#     주차장에 집값이 몇채? 부자아파트 주차장 제대로 돌아보았습니다!
#
# [['desktop.ini', '주차장에 집값이 몇채_ 부자아파트 주차장 제대로 돌아보았습니다! - Korean (auto-generated).srt']]
# /Users/user/Downloads/주차장에 집값이 몇채_ 부자아파트 주차장 제대로 돌아보았습니다! - Korean (auto-generated).srt
# 43
# seed : https://www.youtube.com/watch?v=WE0vyn_9leI&app=desktop
#
#     국내 단 한대!! 40억대 하이퍼카 실물 영접기!!  | 오프라이드오가나(메르세데스 벤츠 SLR 스털링모스 StirlingMoss)
#
# [['desktop.ini', '국내 단 한대!! 40억대 하이퍼카 실물 영접기!! _ 오프라이드오가나(메르세데스 벤츠 SLR 스털링모스 StirlingMoss) - Korean (auto-generated).srt']]
# /Users/user/Downloads/국내 단 한대!! 40억대 하이퍼카 실물 영접기!! _ 오프라이드오가나(메르세데스 벤츠 SLR 스털링모스 StirlingMoss) - Korean (auto-generated).srt
# 44
# seed : https://www.youtube.com/watch?v=DRhVbYdaHh8&app=desktop
# 45
# seed : https://www.youtube.com/watch?v=TFuBIt4qHhY&app=desktop
# 46
# seed : https://www.youtube.com/watch?v=Vz67wo0yjMY&app=desktop
#
#     기업비사 41회 세기의 라이벌, 이병철과 정주영이 만든 기적
#
# [['desktop.ini', '기업비사 41회 세기의 라이벌, 이병철과 정주영이 만든 기적 - Korean (auto-generated).srt']]
# /Users/user/Downloads/기업비사 41회 세기의 라이벌, 이병철과 정주영이 만든 기적 - Korean (auto-generated).srt
# 47
# seed : https://www.youtube.com/watch?v=3SymRAB4b98&app=desktop
# 48
# seed : https://www.youtube.com/watch?v=XuK-e1RKSyA&app=desktop
# 49
# seed : https://www.youtube.com/watch?v=HszH9nU5oMo&app=desktop
# 50
# seed : https://www.youtube.com/watch?v=zG7tvYq_c2k&app=desktop
#
#     (일일뉴스) 문재인, 동맹국 배신으로 폭망!!! / 신의한수 19.07.31
#
# [['(일일뉴스) 문재인, 동맹국 배신으로 폭망!!! _ 신의한수 19.07.31 - Korean (auto-generated).srt', 'desktop.ini']]
# /Users/user/Downloads/(일일뉴스) 문재인, 동맹국 배신으로 폭망!!! _ 신의한수 19.07.31 - Korean (auto-generated).srt
# 51
# seed : https://www.youtube.com/watch?v=HszH9nU5oMo&app=desktop
# 52
# seed : https://www.youtube.com/watch?v=xbBxY4g6nOU&app=desktop
#
#     참다 못한 박용만, 철없는(?) 민주당에 호통! 소름 돋는 연설! (진성호의 직설)
#
# [['desktop.ini', '참다 못한 박용만, 철없는(_) 민주당에 호통! 소름 돋는 연설! (진성호의 직설) - Korean (auto-generated).srt']]
# /Users/user/Downloads/참다 못한 박용만, 철없는(_) 민주당에 호통! 소름 돋는 연설! (진성호의 직설) - Korean (auto-generated).srt
# 53
# seed : https://www.youtube.com/watch?v=sMLSBTAF1i8&app=desktop
#
#     日후쿠시마 제보 "세슘 측정기엔 항상 빨간불 켜져 있다" - 韓日 가정 000씨 [ 김현정의 뉴스쇼 ]
#
# [['desktop.ini', '日후쿠시마 제보 _세슘 측정기엔 항상 빨간불 켜져 있다_ - 韓日 가정 000씨 [ 김현정의 뉴스쇼 ] - Korean (auto-generated).srt']]
# /Users/user/Downloads/日후쿠시마 제보 _세슘 측정기엔 항상 빨간불 켜져 있다_ - 韓日 가정 000씨 [ 김현정의 뉴스쇼 ] - Korean (auto-generated).srt
# 54
# seed : https://www.youtube.com/watch?v=W5ijs9sYDyw&app=desktop
#
#     8/1(목) 풀영상 - 빨간불 후쿠시마 세슘 경보기(제보자 000씨) 조은누리 실종, 3가지 시나리오(손수호) 中군대 홍콩 투입?(우수근) [김현정의 뉴스쇼]
#
# [['8_1(목) 풀영상 - 빨간불 후쿠시마 세슘 경보기(제보자 000씨) 조은누리 실종, 3가지 시나리오(손수호) 中군대 홍콩 투입_(우수근) [김현정의 뉴스쇼] - Korean (auto-generated).srt', 'desktop.ini']]
# /Users/user/Downloads/8_1(목) 풀영상 - 빨간불 후쿠시마 세슘 경보기(제보자 000씨) 조은누리 실종, 3가지 시나리오(손수호) 中군대 홍콩 투입_(우수근) [김현정의 뉴스쇼] - Korean (auto-generated).srt
# 55
# seed : https://www.youtube.com/watch?v=BRRm_wiokcE&app=desktop
#
#     [탐정 손수호] "조은누리 실종, 3가지 시나리오" - 손수호 변호사 [ 김현정의 뉴스쇼 ]
#
# [['desktop.ini', '[탐정 손수호] _조은누리 실종']]
# /Users/user/Downloads/[탐정 손수호] _조은누리 실종
# 56
# seed : https://www.youtube.com/watch?v=biRksT_G3-g&app=desktop
#
#     "中 군대 홍콩 투입? 최악의 최악의 시나리오" - 중국 산동대 우수근 객좌교수 [ 김현정의 뉴스쇼 ]
# seed : https://www.youtube.com/watch?v=436hv4GibXY&app=desktop
#
#     트위지 절대 사지마세요!
#
# [['desktop.ini', '트위지 절대 사지마세요! - Korean (auto-generated).srt']]
# /Users/user/Downloads/트위지 절대 사지마세요! - Korean (auto-generated).srt
# 94
# seed : https://www.youtube.com/watch?v=ljC7kON-PcM&app=desktop
#
#     월매출 1500만원 버는데도 앞으로벌고 뒤로밑지는이유 [추레라기사의 순수익] 1부
#
# [['desktop.ini', '월매출 1500만원 버는데도 앞으로벌고 뒤로밑지는이유 [추레라기사의 순수익] 1부 - Korean (auto-generated).srt']]
# /Users/user/Downloads/월매출 1500만원 버는데도 앞으로벌고 뒤로밑지는이유 [추레라기사의 순수익] 1부 - Korean (auto-generated).srt
# 95
# seed : https://www.youtube.com/watch?v=wStz-AvwFuE&app=desktop
#
#     과속단속 신호위반카메라 이렇게하면 피한다 !! 작동원리 ? 최첨단기술 ? 카메라에 우리가 오해하고 있는것
#
# [['aHR0cHM6Ly93d3cueW91dHViZS5jb20vd2F0Y2g_dj13U3R6LUF2d0Z1RSZhcHA9ZGVza3RvcA,,.txt', 'desktop.ini']]
# /Users/user/Downloads/aHR0cHM6Ly93d3cueW91dHViZS5jb20vd2F0Y2g_dj13U3R6LUF2d0Z1RSZhcHA9ZGVza3RvcA,,.txt
# 96
# seed : https://www.youtube.com/watch?v=ZvPUvkeaMU0&app=desktop
#
#     냄비로 물고기 잔뜩 잡는방법!! 실화니??
#
# [['desktop.ini', '냄비로 물고기 잔뜩 잡는방법!! 실화니__ - Korean (auto-generated).srt']]
# /Users/user/Downloads/냄비로 물고기 잔뜩 잡는방법!! 실화니__ - Korean (auto-generated).srt
# 97
# seed : https://www.youtube.com/watch?v=EtxN8Y9vnFo&app=desktop
#
#     만원짜리 광어회 얼마남을까? 무슨광어를 쓸까? 양은얼마나?
#
# [['desktop.ini', '만원짜리 광어회 얼마남을까_ 무슨광어를 쓸까_ 양은얼마나_ - Korean (auto-generated).srt']]
# /Users/user/Downloads/만원짜리 광어회 얼마남을까_ 무슨광어를 쓸까_ 양은얼마나_ - Korean (auto-generated).srt
# 98
# seed : https://www.youtube.com/watch?v=Uqw_PNKKIjo&app=desktop
#
#     베트남 저가 투어상품의 실태를 살펴보자!(옵션투어, 투어 쇼핑의 진실, 여행사에서 이 영상을 싫어합니다)
#
# [['desktop.ini', '베트남 저가 투어상품의 실태를 살펴보자!(옵션투어, 투어 쇼핑의 진실, 여행사에서 이 영상을 싫어합니다) - Korean (auto-generated).srt']]
# /Users/user/Downloads/베트남 저가 투어상품의 실태를 살펴보자!(옵션투어, 투어 쇼핑의 진실, 여행사에서 이 영상을 싫어합니다) - Korean (auto-generated).srt
# 99
# seed : https://www.youtube.com/watch?v=PFuQHwEsDCc&app=desktop
#
#     수산시장 호객행위 뚫고 내맘대로 흥정해서 골라먹기(속초 동명활어센타 자연산 잡어회와 망챙이 매운탕), Wild Sashimi in Korean Traditional Market
#
# [['desktop.ini', '수산시장 호객행위 뚫고 내맘대로 흥정해서 골라먹기(속초 동명활어센타 자연산 잡어회와 망챙이 매운탕), Wild Sashimi in Korean Traditional Market - Korean (auto-generated).srt']]
# /Users/user/Downloads/수산시장 호객행위 뚫고 내맘대로 흥정해서 골라먹기(속초 동명활어센타 자연산 잡어회와 망챙이 매운탕), Wild Sashimi in Korean Traditional Market - Korean (auto-generated).srt
# 100
# seed : https://www.youtube.com/watch?v=z7PQ7vnnw9I&app=desktop
#
#     제주 올레시장의 신기하고 재밌는 해산물 탐방, 여기오면 꼭 사야할 것들(The Wonderful Seafood of Jeju Traditional Market)
#
# [['desktop.ini', '제주 올레시장의 신기하고 재밌는 해산물 탐방, 여기오면 꼭 사야할 것들(The Wonderful Seafood of Jeju Traditional Market) - Korean (auto-generated).srt']]
# /Users/user/Downloads/제주 올레시장의 신기하고 재밌는 해산물 탐방, 여기오면 꼭 사야할 것들(The Wonderful Seafood of Jeju Traditional Market) - Korean (auto-generated).srt
# 101
# seed : https://www.youtube.com/watch?v=hGUucUkSDkk&app=desktop
#
#     상상 그 이상, 갯가재와 딱새우 [어영차바다야]
#
# [['desktop.ini', '상상 그 이상, 갯가재와 딱새우 [어영차바다야] - Korean (auto-generated).srt']]
# /Users/user/Downloads/상상 그 이상, 갯가재와 딱새우 [어영차바다야] - Korean (auto-generated).srt
# 102
# seed : https://www.youtube.com/watch?v=CWkq1YIJAtw&app=desktop
#
#     새우삼총사 - 보리새우&불새우&닭새우 [어영차바다야]
#
# [['desktop.ini', '새우삼총사 - 보리새우&불새우&닭새우 [어영차바다야] - Korean (auto-generated).srt']]
# /Users/user/Downloads/새우삼총사 - 보리새우&불새우&닭새우 [어영차바다야] - Korean (auto-generated).srt
# 103
# seed : https://www.youtube.com/watch?v=byPwa1ojR3s&app=desktop
#
#     한국기행 - Korea travel_찬바람 불면, 김장 1부 새우 바다를 가다_#001
#
# [['desktop.ini', '한국기행 - Korea travel_찬바람 불면, 김장 1부 새우 바다를 가다_#001 - Korean (auto-generated).srt']]
# /Users/user/Downloads/한국기행 - Korea travel_찬바람 불면, 김장 1부 새우 바다를 가다_#001 - Korean (auto-generated).srt
# 104
# seed : https://www.youtube.com/watch?v=ZHVrFILd3OU&app=desktop
#
#     병어와 민어의 고장, 신안 임자도 [Korea Island]
#
# [['desktop.ini', '병어와 민어의 고장, 신안 임자도 [Korea Island] - Korean (auto-generated).srt']]
# /Users/user/Downloads/병어와 민어의 고장, 신안 임자도 [Korea Island] - Korean (auto-generated).srt
# 105
# seed : https://www.youtube.com/watch?v=m_C4XpyVUoU&app=desktop
#
#     한국에서 가장 비싼 횟감! 이시가리(줄가자미) 회뜨고 폭풍흡입! The most expensive sashimi in Korea/ Roughscale sole [Yummy]
#
# [['desktop.ini', '한국에서 가장 비싼 횟감! 이시가리(줄가자미) 회뜨고 폭풍흡입! The most expensive sashimi in Korea_ Roughscale sole [Yummy] - Korean (auto-generated).srt']]
# /Users/user/Downloads/한국에서 가장 비싼 횟감! 이시가리(줄가자미) 회뜨고 폭풍흡입! The most expensive sashimi in Korea_ Roughscale sole [Yummy] - Korean (auto-generated).srt
# 106
#     예초기날 가는도구와 방법 예초기사용법,예초기날종류 핸드그라인더 사포날 그라인더날 농기계,농자자재 예초기부품 혼다 예초기 잡초,잡초제거,풀,풀제거 귀농귀촌,,농사,농업,농부,주말농장
#
# [['desktop.ini', '예초기날 가는도구와 방법 예초기사용법,예초기날종류 핸드그라인더 사포날 그라인더날 농기계,농자자재 예초기부품 혼다 예초기 잡초,잡초제거,풀,풀제거 귀농귀촌,,농사,농업,농부,주말농장 - Korean (auto-generated).srt']]
# /Users/user/Downloads/예초기날 가는도구와 방법 예초기사용법,예초기날종류 핸드그라인더 사포날 그라인더날 농기계,농자자재 예초기부품 혼다 예초기 잡초,잡초제거,풀,풀제거 귀농귀촌,,농사,농업,농부,주말농장 - Korean (auto-generated).srt
# 114
# seed : https://www.youtube.com/watch?v=M2YQUYqky9U&app=desktop
#
#     brush cutter / #예초기 꼭 알아야 할것들 #초간단수리 #안전 #보관
#
# [['brush cutter _ #예초기 꼭 알아야 할것들 #초간단수리 #안전 #보관 - Korean (auto-generated).srt', 'desktop.ini']]
# /Users/user/Downloads/brush cutter _ #예초기 꼭 알아야 할것들 #초간단수리 #안전 #보관 - Korean (auto-generated).srt
# 115
# seed : https://www.youtube.com/watch?v=J7AhHdS-2i4&app=desktop
#
#     예초기 시동꺼지고 rpm불규칙 하고 찐바날때 5분수리법 Initial startup 제초기  농기계,예초기날,잡초,잡초제거,풀제거,벌초,예취기사용방법,예초기수리,귀농,귀촌,농사
#
# [['desktop.ini', '예초기 시동꺼지고 rpm불규칙 하고 찐바날때 5분수리법 Initial startup 제초기 농기계,예초기날,잡초,잡초제거,풀제거,벌초,예취기사용방법,예초기수리,귀농,귀촌,농사 - Korean (auto-generated).srt']]
# /Users/user/Downloads/예초기 시동꺼지고 rpm불규칙 하고 찐바날때 5분수리법 Initial startup 제초기 농기계,예초기날,잡초,잡초제거,풀제거,벌초,예취기사용방법,예초기수리,귀농,귀촌,농사 - Korean (auto-generated).srt
# 116
# seed : https://www.youtube.com/watch?v=rDPOnQLZBmo&app=desktop
#
#     비닐하우스비닐 20 년 이상 오래쓰기 농막 원두막 차광막 차광망 그늘막 간이창고 조립식창고 차광막종류 농자재  비닐하우스자재 농자재 귀농 귀촌 농사 농업 농부 텃밭 주말농장
#
# [['desktop.ini', '비닐하우스비닐 20 년 이상 오래쓰기 농막 원두막 차광막 차광망 그늘막 간이창고 조립식창고 차광막종류 농자재 비닐하우스자재 농자재 귀농 귀촌 농사 농업 농부 텃밭 주말농장 - Korean (auto-generated).srt']]
# /Users/user/Downloads/비닐하우스비닐 20 년 이상 오래쓰기 농막 원두막 차광막 차광망 그늘막 간이창고 조립식창고 차광막종류 농자재 비닐하우스자재 농자재 귀농 귀촌 농사 농업 농부 텃밭 주말농장 - Korean (auto-generated).srt
# 117
# seed : https://www.youtube.com/watch?v=J7AhHdS-2i4&app=desktop
# 118
# seed : https://www.youtube.com/watch?v=BVJLvRmvPiA&app=desktop
#
#     공구 전문가 다이소 제품 구입!! 아이디어상품 진짜 리뷰 간다!!
#
# [['desktop.ini', '공구 전문가 다이소 제품 구입!! 아이디어상품 진짜 리뷰 간다!! - Korean (auto-generated).srt']]
# /Users/user/Downloads/공구 전문가 다이소 제품 구입!! 아이디어상품 진짜 리뷰 간다!! - Korean (auto-generated).srt
# 119
# seed : https://www.youtube.com/watch?v=lTBH2T1M7t4&app=desktop
#
#     용접기 한대에!! 알곤용접 , 프라즈마절단 , 아크용접까지
#
# [['desktop.ini', '용접기 한대에!! 알곤용접 , 프라즈마절단 , 아크용접까지 - Korean (auto-generated).srt']]
# /Users/user/Downloads/용접기 한대에!! 알곤용접 , 프라즈마절단 , 아크용접까지 - Korean (auto-generated).srt
# 120
# seed : https://www.youtube.com/watch?v=IklLAZ_ItA0&app=desktop
# 121
# seed : https://www.youtube.com/watch?v=lKwLXbMYkxE&app=desktop
# 122
# seed : https://www.youtube.com/watch?v=YscG26fmkig&app=desktop
#
#     30년된 분배기교체방법 에어빼기방법 난방비절약방법 난방수순환방법 보일러 배관청소방법 부천 편
#
# [['30년된 분배기교체방법 에어빼기방법 난방비절약방법 난방수순환방법 보일러 배관청소방법 부천 편 - Korean (auto-generated).srt', 'desktop.ini']]
# /Users/user/Downloads/30년된 분배기교체방법 에어빼기방법 난방비절약방법 난방수순환방법 보일러 배관청소방법 부천 편 - Korean (auto-generated).srt
# 123
# seed : https://www.youtube.com/watch?v=FQQeFA1Xuu4&app=desktop
#
#     [에어컨설치 굳뉴스]에어컨철거 / 펌프다운(에어컨가스회수방법)
#
# [['desktop.ini', '[에어컨설치 굳뉴스]에어컨철거 _ 펌프다운(에어컨가스회수방법) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[에어컨설치 굳뉴스]에어컨철거 _ 펌프다운(에어컨가스회수방법) - Korean (auto-generated).srt
# 124
# seed : https://www.youtube.com/watch?v=n3S2-k1dIE8&app=desktop
#
#     보일러 배관청소#2
#
# [['desktop.ini', '보일러 배관청소#2 - Korean (auto-generated).srt']]
# /Users/user/Downloads/보일러 배관청소#2 - Korean (auto-generated).srt
# 125
# seed : https://www.youtube.com/watch?v=zvb2dDG3M1o&app=desktop
#
#     [ 물통 청소 ] 보일러는 타는데.. 방은 왜 추울까..? Cleaning boiler water bucket
#
# [['desktop.ini', '[ 물통 청소 ] 보일러는 타는데.. 방은 왜 추울까.._ Cleaning boiler water bucket - Korean (auto-generated).srt']]
# /Users/user/Downloads/[ 물통 청소 ] 보일러는 타는데.. 방은 왜 추울까.._ Cleaning boiler water bucket - Korean (auto-generated).srt
# 126
# seed : https://www.youtube.com/watch?v=2DEZQKX0i_8&app=desktop
#
#     보일러 배관 공기빼기 방법
#
# [['desktop.ini', '보일러 배관 공기빼기 방법 - Korean.srt']]
# /Users/user/Downloads/보일러 배관 공기빼기 방법 - Korean.srt
# 127
# seed : https://www.youtube.com/watch?v=CX_m-XiLm1Q&app=desktop
#
#     난방겸용 벽난로 / 보일러겸용 벽난로 --------------------! [ 금강최고벽난로 ]
#
# [['desktop.ini', '난방겸용 벽난로 _ 보일러겸용 벽난로 --------------------! [ 금강최고벽난로 ] - Korean.srt']]
# /Users/user/Downloads/난방겸용 벽난로 _ 보일러겸용 벽난로 --------------------! [ 금강최고벽난로 ] - Korean.srt
# 128
# seed : https://www.youtube.com/watch?v=m8fmlWDCyDc&app=desktop
# 129
# seed : https://www.youtube.com/watch?v=GfefkCgQ8hc&app=desktop
#
#     mix특집다큐 따뜻한 적정기술 히말라야에 온정을 전하다 150309 HDTV H264 720p WITH
#
# [['desktop.ini', 'mix특집다큐 따뜻한 적정기술 히말라야에 온정을 전하다 150309 HDTV H264 720p WITH - Korean (auto-generated).srt']]
# /Users/user/Downloads/mix특집다큐 따뜻한 적정기술 히말라야에 온정을 전하다 150309 HDTV H264 720p WITH - Korean (auto-generated).srt
# 130
# seed : https://www.youtube.com/watch?v=BweabXqfwJ4&app=desktop
#
#     하나뿐인 지구 - Only One Earth_자립하는 삶을 만드는 친환경 적정기술_#001
#
# [['desktop.ini', '하나뿐인 지구 - Only One Earth_자립하는 삶을 만드는 친환경 적정기술_#001 - Korean (auto-generated).srt']]
# /Users/user/Downloads/하나뿐인 지구 - Only One Earth_자립하는 삶을 만드는 친환경 적정기술_#001 - Korean (auto-generated).srt
# 131
# seed : https://www.youtube.com/watch?v=d0Nz3lU_MS0&app=desktop
#
#     하나뿐인 지구 - Only One Earth_자립하는 삶을 만드는 친환경 적정기술_#002
#
# [['desktop.ini', '하나뿐인 지구 - Only One Earth_자립하는 삶을 만드는 친환경 적정기술_#002 - Korean (auto-generated).srt']]
# /Users/user/Downloads/하나뿐인 지구 - Only One Earth_자립하는 삶을 만드는 친환경 적정기술_#002 - Korean (auto-generated).srt
# 132
# seed : https://www.youtube.com/watch?v=wE01kX5LVv8&app=desktop
#
#     하나뿐인 지구 - Only One Earth_자립하는 삶을 만드는 친환경 적정기술_#004
#
# [['desktop.ini', '하나뿐인 지구 - Only One Earth_자립하는 삶을 만드는 친환경 적정기술_#004 - Korean (auto-generated).srt']]
# /Users/user/Downloads/하나뿐인 지구 - Only One Earth_자립하는 삶을 만드는 친환경 적정기술_#004 - Korean (auto-generated).srt
# 133
# seed : https://www.youtube.com/watch?v=2dkGDCZUzgk&app=desktop
# 134
# seed : https://www.youtube.com/watch?v=XKFZaa5c73k&app=desktop
# 135
# seed : https://www.youtube.com/watch?v=TrDS50S58CY&app=desktop
# 136
# seed : https://www.youtube.com/watch?v=XKFZaa5c73k&app=desktop
# 137
# seed : https://www.youtube.com/watch?v=5mOFu3uty58&app=desktop
# 138
# seed : https://www.youtube.com/watch?v=aftK2wK7CFw&app=desktop
#
#     극한직업 - Extreme JOB_베트남 목선 제작-2부_#003
#
# [['desktop.ini', '극한직업 - Extreme JOB_베트남 목선 제작-2부_#003 - Korean (auto-generated).srt']]
# /Users/user/Downloads/극한직업 - Extreme JOB_베트남 목선 제작-2부_#003 - Korean (auto-generated).srt
# 139
# seed : https://www.youtube.com/watch?v=NfnYV_fYQ6M&app=desktop
# 140
# seed : https://www.youtube.com/watch?v=rHjO3xjDJAo&app=desktop
#
#     극한직업 - Extreme JOB, 멧돼지 포획단 제1부
#
# [['desktop.ini', '극한직업 - Extreme JOB, 멧돼지 포획단 제1부 - Korean (auto-generated).srt']]
# /Users/user/Downloads/극한직업 - Extreme JOB, 멧돼지 포획단 제1부 - Korean (auto-generated).srt
# 141
# seed : https://www.youtube.com/watch?v=2zjTDjQoLoQ&app=desktop
#
#     영등포지구대에 잡혀오는 사람들
#
# [['desktop.ini', '영등포지구대에 잡혀오는 사람들 - Korean (auto-generated).srt']]
# /Users/user/Downloads/영등포지구대에 잡혀오는 사람들 - Korean (auto-generated).srt
# 142
# seed : https://www.youtube.com/watch?v=ywn4yDOP6ps&app=desktop
#
#     알몸으로 도심을 누비는 남자 [현장르포 특종세상 259회]
#
# [['desktop.ini', '알몸으로 도심을 누비는 남자 [현장르포 특종세상 259회] - Korean (auto-generated).srt']]
# /Users/user/Downloads/알몸으로 도심을 누비는 남자 [현장르포 특종세상 259회] - Korean (auto-generated).srt
# 143
# seed : https://www.youtube.com/watch?v=ujPKxKxtuwo&app=desktop
#
#     임예진 이혼? 남편과 각방 생활 20년 된 이유. 임예진 남편 최창욱과 결혼 이유?
#
# [['desktop.ini', '임예진 이혼_ 남편과 각방 생활 20년 된 이유. 임예진 남편 최창욱과 결혼 이유_ - Korean (auto-generated).srt']]
# /Users/user/Downloads/임예진 이혼_ 남편과 각방 생활 20년 된 이유. 임예진 남편 최창욱과 결혼 이유_ - Korean (auto-generated).srt
# 144
# seed : https://www.youtube.com/watch?v=cgCHCUr8YZk&app=desktop
#
#     1년간 누워만 지내던 220KG 초고도 비만 주부의 놀랍고 아름다운 변화!!
#
# [['1년간 누워만 지내던 220KG 초고도 비만 주부의 놀랍고 아름다운 변화!! - Korean (auto-generated).srt', 'desktop.ini']]
# /Users/user/Downloads/1년간 누워만 지내던 220KG 초고도 비만 주부의 놀랍고 아름다운 변화!! - Korean (auto-generated).srt
# 145
# seed : https://www.youtube.com/watch?v=FNCN_BuOuVI&app=desktop
#
#     채널A 특별기획 내 생애 마지막 다이어트 뱃살을 잡아라 180826 방송분
#
# [['desktop.ini', '채널A 특별기획 내 생애 마지막 다이어트 뱃살을 잡아라 180826 방송분 - Korean (auto-generated).srt']]
# /Users/user/Downloads/채널A 특별기획 내 생애 마지막 다이어트 뱃살을 잡아라 180826 방송분 - Korean (auto-generated).srt
# 146
# seed : https://www.youtube.com/watch?v=XVP_caGccGU&app=desktop
#
#     [특별기획] 우리 몸을 살리는 편식 1편 - 0.02g의 힘, 현미
#
# [['desktop.ini', '[특별기획] 우리 몸을 살리는 편식 1편 - 0.02g의 힘, 현미 - Korean (auto-generated).srt']]
# /Users/user/Downloads/[특별기획] 우리 몸을 살리는 편식 1편 - 0.02g의 힘, 현미 - Korean (auto-generated).srt
# 147
# seed : https://www.youtube.com/watch?v=7rNxzbAhEDI&app=desktop
#
#     [특별기획] 우리 몸을 살리는 편식 2편 - 현미, 식탁을 구하다
#
# [['desktop.ini', '[특별기획] 우리 몸을 살리는 편식 2편 - 현미, 식탁을 구하다 - Korean (auto-generated).srt']]
# /Users/user/Downloads/[특별기획] 우리 몸을 살리는 편식 2편 - 현미, 식탁을 구하다 - Korean (auto-generated).srt
# 148
# seed : https://www.youtube.com/watch?v=qtkqhUonajU&app=desktop
#
#     '육식의 반란3 - 팝콘치킨의 고백' 전주MBC 유룡 기자, 올해의방송기자상, 2014년12월05일 방송
#
# [["'육식의 반란3 - 팝콘치킨의 고백' 전주MBC 유룡 기자, 올해의방송기자상, 2014년12월05일 방송 - Korean (auto-generated).srt", 'desktop.ini']]
# /Users/user/Downloads/'육식의 반란3 - 팝콘치킨의 고백' 전주MBC 유룡 기자, 올해의방송기자상, 2014년12월05일 방송 - Korean (auto-generated).srt
# 149
# seed : https://www.youtube.com/watch?v=LzyO1oL-QeQ&app=desktop
# 150
# seed : https://www.youtube.com/watch?v=zoE5ndPaFa8&app=desktop
#
#     다큐 오늘 - 캄보디아에 우기가 오면
#
# [['desktop.ini', '다큐 오늘 - 캄보디아에 우기가 오면 - Korean (auto-generated).srt']]
# /Users/user/Downloads/다큐 오늘 - 캄보디아에 우기가 오면 - Korean (auto-generated).srt
# 151
# seed : https://www.youtube.com/watch?v=gtp4VZqu6s8&app=desktop
#
#     세계테마기행 - 알면 알수록 궁금한 미얀마 1부- 호수에 살다, 인따족_#002
#
# [['desktop.ini', '세계테마기행 - 알면 알수록 궁금한 미얀마 1부- 호수에 살다, 인따족_#002 - Korean (auto-generated).srt']]
# /Users/user/Downloads/세계테마기행 - 알면 알수록 궁금한 미얀마 1부- 호수에 살다, 인따족_#002 - Korean (auto-generated).srt
# 152
# seed : https://www.youtube.com/watch?v=J29MsvZciUo&app=desktop
#
#     세계테마기행 - 알면 알수록 궁금한 미얀마 2부- 삶을 달리는 순환열차_#002
#
# [['desktop.ini', '세계테마기행 - 알면 알수록 궁금한 미얀마 2부- 삶을 달리는 순환열차_#002 - Korean (auto-generated).srt']]
# /Users/user/Downloads/세계테마기행 - 알면 알수록 궁금한 미얀마 2부- 삶을 달리는 순환열차_#002 - Korean (auto-generated).srt
# 153
# seed : https://www.youtube.com/watch?v=MlkcpumpuNA&app=desktop
#
#     [미얀마] 시포 옷 수선집에서 생긴일....
#
# [['desktop.ini', '[미얀마] 시포 옷 수선집에서 생긴일.... - Korean (auto-generated).srt']]
# /Users/user/Downloads/[미얀마] 시포 옷 수선집에서 생긴일.... - Korean (auto-generated).srt
# 154
# seed : https://www.youtube.com/watch?v=RYkXemNfIhQ&app=desktop
#
#     [미얀마] 시포에서 동네 한 바퀴
#
# [['desktop.ini', '[미얀마] 시포에서 동네 한 바퀴 - Korean (auto-generated).srt']]
# /Users/user/Downloads/[미얀마] 시포에서 동네 한 바퀴 - Korean (auto-generated).srt
# 155
# seed : https://www.youtube.com/watch?v=MlkcpumpuNA&app=desktop
# 156
# seed : https://www.youtube.com/watch?v=ep40wOX9ofw&app=desktop
#
#     라오스에서 사업하지마세요. 베트남 태국 필리핀 캄보디아 미얀마
#
# [['desktop.ini', '라오스에서 사업하지마세요. 베트남 태국 필리핀 캄보디아 미얀마 - Korean (auto-generated).srt']]
# /Users/user/Downloads/라오스에서 사업하지마세요. 베트남 태국 필리핀 캄보디아 미얀마 - Korean (auto-generated).srt
# 157
# seed : https://www.youtube.com/watch?v=HpIKbGIc2Ws&app=desktop
#
#     20대 라오스 생존방법(경험)
#
# [['20대 라오스 생존방법(경험) - Korean (auto-generated).srt', 'desktop.ini']]
# /Users/user/Downloads/20대 라오스 생존방법(경험) - Korean (auto-generated).srt
# 158
# seed : https://www.youtube.com/watch?v=o2KxHzJU9xE&app=desktop
# 159
# seed : https://www.youtube.com/watch?v=GxmImosxrXA&app=desktop
#
#     라오스 Q&A 생활/여행
#
# [['desktop.ini', '라오스 Q&A 생활_여행 - Korean (auto-generated).srt']]
# /Users/user/Downloads/라오스 Q&A 생활_여행 - Korean (auto-generated).srt
# 160
# seed : https://www.youtube.com/watch?v=tiWy0LpH81U&app=desktop
#
#     라오스최대규모 산지앙시장-비엔티엔 중심지의 중국인 상인들
#
# [['desktop.ini', '라오스최대규모 산지앙시장-비엔티엔 중심지의 중국인 상인들 - Korean (auto-generated).srt']]
# /Users/user/Downloads/라오스최대규모 산지앙시장-비엔티엔 중심지의 중국인 상인들 - Korean (auto-generated).srt
# 161
# seed : https://www.youtube.com/watch?v=AkmYX5UrTF0&app=desktop
#
#     라오스아파트 원룸 좌표/저.중.고 비교 한달살기
#
# [['desktop.ini', '라오스아파트 원룸 좌표_저.중.고 비교 한달살기 - Korean (auto-generated).srt']]
# /Users/user/Downloads/라오스아파트 원룸 좌표_저.중.고 비교 한달살기 - Korean (auto-generated).srt
# 162
# seed : https://www.youtube.com/watch?v=fg5JSHK6odg&app=desktop
#
#     치앙마이 한달살기 | 🇹🇭태국의 물가 (feat.현지물가 체감 꿀팁)
#
# [['desktop.ini', '치앙마이 한달살기 _ 🇹🇭태국의 물가 (feat.현지물가 체감 꿀팁) - Korean (auto-generated).srt']]
# /Users/user/Downloads/치앙마이 한달살기 _ 🇹🇭태국의 물가 (feat.현지물가 체감 꿀팁) - Korean (auto-generated).srt
# 163
# seed : https://www.youtube.com/watch?v=Wqwan41ytuA&app=desktop
#
#     라오스요정 Q&A 소통 라이브
#
# [['desktop.ini', '라오스요정 Q&A 소통 라이브 - Korean (auto-generated).srt']]
# /Users/user/Downloads/라오스요정 Q&A 소통 라이브 - Korean (auto-generated).srt
# 164
# seed : https://www.youtube.com/watch?v=EHm1Os6WpSg&app=desktop
#
#     라오스 터줏대감과 소통
#
# [['desktop.ini', '라오스 터줏대감과 소통 - Korean (auto-generated).srt']]
# /Users/user/Downloads/라오스 터줏대감과 소통 - Korean (auto-generated).srt
# 165
# seed : https://www.youtube.com/watch?v=mvXX51e9Z78&app=desktop
#
#     유승준 이젠 정말 안녕
#
# [['desktop.ini', '유승준 이젠 정말 안녕 - Korean (auto-generated).srt']]
# /Users/user/Downloads/유승준 이젠 정말 안녕 - Korean (auto-generated).srt
# 166
# seed : https://www.youtube.com/watch?v=dmq6rWEULP8&app=desktop
#
#     2118년도에 다녀온 시간여행자가 밝히는 엄청난 진실
#
# [['2118년도에 다녀온 시간여행자가 밝히는 엄청난 진실 - Korean (auto-generated).srt', 'desktop.ini']]
# /Users/user/Downloads/2118년도에 다녀온 시간여행자가 밝히는 엄청난 진실 - Korean (auto-generated).srt
# 167
# seed : https://www.youtube.com/watch?v=Q2nMVMBZ4NE&app=desktop
#
#     【전체리뷰/로마의 휴일】 세상 모든 로맨틱코미디의 시작
#
# [['desktop.ini', '【전체리뷰_로마의 휴일】 세상 모든 로맨틱코미디의 시작 - Korean (auto-generated).srt']]
# /Users/user/Downloads/【전체리뷰_로마의 휴일】 세상 모든 로맨틱코미디의 시작 - Korean (auto-generated).srt
# 168
# seed : https://www.youtube.com/watch?v=ubv6uPvckFU&app=desktop
#
#     파리의 연인 1회 핵심만 다시 또보기🔎 ＂당신 해고야＂《박신양, 김정은, 이동건, 김서형 / 드라마 또보기 / 스브스캐치》
#
# [['desktop.ini', '파리의 연인 1회 핵심만 다시 또보기🔎 ＂당신 해고야＂《박신양, 김정은, 이동건, 김서형 _ 드라마 또보기 _ 스브스캐치》 - Korean (auto-generated).srt']]
# /Users/user/Downloads/파리의 연인 1회 핵심만 다시 또보기🔎 ＂당신 해고야＂《박신양, 김정은, 이동건, 김서형 _ 드라마 또보기 _ 스브스캐치》 - Korean (auto-generated).srt
# 169
# seed : https://www.youtube.com/watch?v=UvkA0QSUrW8&app=desktop
#
#     Dong Yi, 45회, EP45, #04
#
# [['desktop.ini', 'Dong Yi, 45회, EP45, #04 - Korean (auto-generated).srt']]
# /Users/user/Downloads/Dong Yi, 45회, EP45, #04 - Korean (auto-generated).srt
# 170
# seed : https://www.youtube.com/watch?v=WLUCLfxKO1Q&app=desktop
#
#     Dong Yi, 44회, EP44, #07
#
# [['desktop.ini', 'Dong Yi, 44회, EP44, #07 - Korean (auto-generated).srt']]
# /Users/user/Downloads/Dong Yi, 44회, EP44, #07 - Korean (auto-generated).srt
# 171
# seed : https://www.youtube.com/watch?v=IStc9gYed-c&app=desktop
# 172
# seed : https://www.youtube.com/watch?v=WLUCLfxKO1Q&app=desktop
# 173
# seed : https://www.youtube.com/watch?v=i2R9N_tslZw&app=desktop
# 174
# seed : https://www.youtube.com/watch?v=Ew46bsqIdeE&app=desktop
#     Dong Yi, 45회, EP45, #01
#
# [['desktop.ini', 'Dong Yi, 45회, EP45, #01 - Korean (auto-generated).srt']]
# /Users/user/Downloads/Dong Yi, 45회, EP45, #01 - Korean (auto-generated).srt
# 175
# seed : https://www.youtube.com/watch?v=UvkA0QSUrW8&app=desktop
# 176
# seed : https://www.youtube.com/watch?v=3rFHi0AdZEM&app=desktop
# 177
# seed : https://www.youtube.com/watch?v=WLUCLfxKO1Q&app=desktop
# 178
# seed : https://www.youtube.com/watch?v=i2R9N_tslZw&app=desktop
# 179
# seed : https://www.youtube.com/watch?v=WLUCLfxKO1Q&app=desktop
# 180
# seed : https://www.youtube.com/watch?v=3rFHi0AdZEM&app=desktop
# 181
# seed : https://www.youtube.com/watch?v=lvpdMvKYLxo&app=desktop
#
#     Dong Yi, 45회, EP45, #07
#
# [['desktop.ini', 'Dong Yi, 45회, EP45, #07 - Korean (auto-generated).srt']]
# /Users/user/Downloads/Dong Yi, 45회, EP45, #07 - Korean (auto-generated).srt
# 182
# seed : https://www.youtube.com/watch?v=p_-gQ6fxpQQ&app=desktop
# 183
#
#     이재주/품바 만능재주꾼~빵빵 터진 관객분들/2017년9월24일:금산 세계 인삼엑스포
#
# [['desktop.ini', '이재주_품바 만능재주꾼_빵빵 터진 관객분들_2017년9월24일_금산 세계 인삼엑스포 - Korean (auto-generated).srt']]
# /Users/user/Downloads/이재주_품바 만능재주꾼_빵빵 터진 관객분들_2017년9월24일_금산 세계 인삼엑스포 - Korean (auto-generated).srt
# 194
# seed : https://www.youtube.com/watch?v=9hu8v11ZMlY&app=desktop
#
#     점팔이 / 👍만담 꽁트 맨트와 표정관리 때문에...역시👍:2018년5월1일(야간)함평 나비축제
#
# [['desktop.ini', '점팔이 _ 👍만담 꽁트 맨트와 표정관리 때문에...역시👍_2018년5월1일(야간)함평 나비축제 - Korean (auto-generated).srt']]
# /Users/user/Downloads/점팔이 _ 👍만담 꽁트 맨트와 표정관리 때문에...역시👍_2018년5월1일(야간)함평 나비축제 - Korean (auto-generated).srt
# 195
# seed : https://www.youtube.com/watch?v=VPsz1ceLeS0&app=desktop
# 196
# seed : https://www.youtube.com/watch?v=5qcag6VSGaY&app=desktop
#
#     ♡버드리♡12월16일  군수님 버드리한테 영동곶감 선물 내년에도 올게요
#
# [['desktop.ini', '♡버드리♡12월16일 군수님 버드리한테 영동곶감 선물 내년에도 올게요 - Korean (auto-generated).srt']]
# /Users/user/Downloads/♡버드리♡12월16일 군수님 버드리한테 영동곶감 선물 내년에도 올게요 - Korean (auto-generated).srt
# 197
# seed : https://www.youtube.com/watch?v=RA6ZfxMdoAY&app=desktop
# 198
# seed : https://www.youtube.com/watch?v=u_ceEjKB8I4&app=desktop
#
#     ''엉뚱 발랄!강원도소녀 나공주품바님''과 삼식이품바님은 ''환상의 콤비!?''~ㅎㅎ 대박♡
#
# [["''엉뚱 발랄!강원도소녀 나공주품바님''과 삼식이품바님은 ''환상의 콤비!_''_ㅎㅎ 대박♡ - Korean (auto-generated).srt", 'desktop.ini']]
# /Users/user/Downloads/''엉뚱 발랄!강원도소녀 나공주품바님''과 삼식이품바님은 ''환상의 콤비!_''_ㅎㅎ 대박♡ - Korean (auto-generated).srt
# 199
# seed : https://www.youtube.com/watch?v=R3YjYL1duM4&app=desktop
#
#     배꼽주의!삼식이 품바와 나공주품바 듀엣공연
#
# [['desktop.ini', '배꼽주의!삼식이 품바와 나공주품바 듀엣공연 - Korean (auto-generated).srt']]
# /Users/user/Downloads/배꼽주의!삼식이 품바와 나공주품바 듀엣공연 - Korean (auto-generated).srt
# 200
# seed : https://www.youtube.com/watch?v=u_ceEjKB8I4&app=desktop
# 201
# seed : https://www.youtube.com/watch?v=XSyLEV7kaRE&app=desktop
#
#     작은거인♡윤정단장이 극찬하는/짱구@품바의 북&장구 진 면목Pumba Dancu drum, Jung-gu Nanta performance
#
# [['desktop.ini', '작은거인♡윤정단장이 극찬하는_짱구@품바의 북&장구 진 면목Pumba Dancu drum, Jung-gu Nanta performance - Korean (auto-generated).srt']]
# /Users/user/Downloads/작은거인♡윤정단장이 극찬하는_짱구@품바의 북&장구 진 면목Pumba Dancu drum, Jung-gu Nanta performance - Korean (auto-generated).srt
# 202
# seed : https://www.youtube.com/watch?v=-jKsVH_84Xs&app=desktop
#
#     🍒윤정품바🍒삼백만원에 하니 사가쑈 웃음 바다ㅋㅋ작은거인 예술단🎈법성포 2018단오제🎈마지막날 저녁공연(능이)
#
# [['desktop.ini', '🍒윤정품바🍒삼백만원에 하니 사가쑈 웃음 바다ㅋㅋ작은거인 예술단🎈법성포 2018단오제🎈마지막날 저녁공연(능이) - Korean (auto-generated).srt']]
# /Users/user/Downloads/🍒윤정품바🍒삼백만원에 하니 사가쑈 웃음 바다ㅋㅋ작은거인 예술단🎈법성포 2018단오제🎈마지막날 저녁공연(능이) - Korean (auto-generated).srt
# 203
# seed : https://www.youtube.com/watch?v=hdZUv_fl4v0&app=desktop
# 204
# seed : https://www.youtube.com/watch?v=4pTnNYcDQyE&app=desktop
#
#     누가 부르냐에 따라 색다른 ♬ 보릿고개 ♬ | 원곡가수 진성 ⭐️ 하동 트로트신동 정동원
#
# [['desktop.ini', '누가 부르냐에 따라 색다른 ♬ 보릿고개 ♬ _ 원곡가수 진성 ⭐️ 하동 트로트신동 정동원 - Korean (auto-generated).srt']]
# /Users/user/Downloads/누가 부르냐에 따라 색다른 ♬ 보릿고개 ♬ _ 원곡가수 진성 ⭐️ 하동 트로트신동 정동원 - Korean (auto-generated).srt
# 205
# seed : https://www.youtube.com/watch?v=08ycJ5MPBmM&app=desktop
#
#     [뉴스] 송가인의 마법 (TV조선 먹여 살리는 송가인, 뽕 따러 가세) (TV조선, 뉴스현장, 20190720)
#
# [['desktop.ini', '[뉴스] 송가인의 마법 (TV조선 먹여 살리는 송가인, 뽕 따러 가세) (TV조선, 뉴스현장, 20190720) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[뉴스] 송가인의 마법 (TV조선 먹여 살리는 송가인, 뽕 따러 가세) (TV조선, 뉴스현장, 20190720) - Korean (auto-generated).srt
# 206
# seed : https://www.youtube.com/watch?v=B2KvWEMPoWA&app=desktop
#
#     TV조선 미스트롯 진 송가인 뽕따러가세 1회 1호 사연-46호 오라버니
#
# [['desktop.ini', 'TV조선 미스트롯 진 송가인 뽕따러가세 1회 1호 사연-46호 오라버니 - Korean (auto-generated).srt']]
# /Users/user/Downloads/TV조선 미스트롯 진 송가인 뽕따러가세 1회 1호 사연-46호 오라버니 - Korean (auto-generated).srt
# 207
# ...
#
#     YTN 김창옥의 소나기(2회) 강연 - 혼자 짊어지지 마라!
#
# [['desktop.ini', 'YTN 김창옥의 소나기(2회) 강연 - 혼자 짊어지지 마라! - Korean (auto-generated).srt']]
# /Users/user/Downloads/YTN 김창옥의 소나기(2회) 강연 - 혼자 짊어지지 마라! - Korean (auto-generated).srt
# 434
# seed : https://www.youtube.com/watch?v=4yEqxx6-Aj0&app=desktop
#
#     [400회][자막] 밝은 성격 웃는 얼굴 뒤에 나도 몰래 울고 있던 나 / 김창옥 포프리쇼 / 강연
#
# /Users/user/Downloads/간단하게 석부작 만들어 풍란 키우기 raise orchid - Korean (auto-generated).srt
# 452
# seed : https://www.youtube.com/watch?v=fdSrSvmgnRU&app=desktop
#
#     석부작 만드는법 왜철쭉 돌붙임
#
# [['desktop.ini', '석부작 만드는법 왜철쭉 돌붙임 - Korean (auto-generated).srt']]
# /Users/user/Downloads/석부작 만드는법 왜철쭉 돌붙임 - Korean (auto-generated).srt
# 453
# seed : https://www.youtube.com/watch?v=NlcxAxGO3Xs&app=desktop
#
#     [다육이키우기#45] "원종에보니" 영상하나로 끝|특성+사는법+주의할점|
#
# [['desktop.ini', '[다육이키우기#45] _원종에보니_ 영상하나로 끝_특성+사는법+주의할점_ - Korean (auto-generated).srt']]
# /Users/user/Downloads/[다육이키우기#45] _원종에보니_ 영상하나로 끝_특성+사는법+주의할점_ - Korean (auto-generated).srt
# 454
# seed : https://www.youtube.com/watch?v=tpMk9QGHjbc&app=desktop
# 455
# seed : https://www.youtube.com/watch?v=sSB8RVvWW50&app=desktop
#
#     [다육이키우기#29] 가을에 예뻐지는 다육2탄|
#
# [['desktop.ini', '[다육이키우기#29] 가을에 예뻐지는 다육2탄_ - Korean (auto-generated).srt']]
# /Users/user/Downloads/[다육이키우기#29] 가을에 예뻐지는 다육2탄_ - Korean (auto-generated).srt
# 456
# seed : https://www.youtube.com/watch?v=F5oDBLuQweQ&app=desktop
#
#     [다육이키우기#30] 공중뿌리 보이면 분갈이 해야합니다.
#
# [['desktop.ini', '[다육이키우기#30] 공중뿌리 보이면 분갈이 해야합니다. - Korean (auto-generated).srt']]
# /Users/user/Downloads/[다육이키우기#30] 공중뿌리 보이면 분갈이 해야합니다. - Korean (auto-generated).srt
# 457
# seed : https://www.youtube.com/watch?v=-xpH6ThGp74&app=desktop
#
#     [다육이키우기#33] 가을에 예뻐지는 다육 5탄|단아한 종류 8종 소개|
#
# [['desktop.ini', '[다육이키우기#33] 가을에 예뻐지는 다육 5탄_단아한 종류 8종 소개_ - Korean (auto-generated).srt']]
# /Users/user/Downloads/[다육이키우기#33] 가을에 예뻐지는 다육 5탄_단아한 종류 8종 소개_ - Korean (auto-generated).srt
# 458
# seed : https://www.youtube.com/watch?v=X7DZUQSQKF0&app=desktop
#
#     [다육이키우기#36] 가을에 예뻐지는 다육 7탄| 라울에 대한 모든 이야기|
#
# [['desktop.ini', '[다육이키우기#36] 가을에 예뻐지는 다육 7탄_ 라울에 대한 모든 이야기_ - Korean (auto-generated).srt']]
# /Users/user/Downloads/[다육이키우기#36] 가을에 예뻐지는 다육 7탄_ 라울에 대한 모든 이야기_ - Korean (auto-generated).srt
# 459
# seed : https://www.youtube.com/watch?v=3bVBWSafgjk&app=desktop
#
#     [다육이키우기#39] 가을에 예뻐지는 다육 약 50종 |1편~7편 풀영상|
#
# [['desktop.ini', '[다육이키우기#39] 가을에 예뻐지는 다육 약 50종 _1편_7편 풀영상_ - Korean (auto-generated).srt']]
# /Users/user/Downloads/[다육이키우기#39] 가을에 예뻐지는 다육 약 50종 _1편_7편 풀영상_ - Korean (auto-generated).srt
# 460
# seed : https://www.youtube.com/watch?v=BGo_W14PmgY&app=desktop
#
#     [다육이키우기#42] 긴 화분 분갈이 꿀팁 | 여름분갈이(짧은영상)|
#
# [['desktop.ini', '[다육이키우기#42] 긴 화분 분갈이 꿀팁 _ 여름분갈이(짧은영상)_ - Korean (auto-generated).srt']]
# /Users/user/Downloads/[다육이키우기#42] 긴 화분 분갈이 꿀팁 _ 여름분갈이(짧은영상)_ - Korean (auto-generated).srt
# 461
# seed : https://www.youtube.com/watch?v=_ppTX8f-NSY&app=desktop
#
#     [초보학습#9] 다육식물 병충해 종류와 원인, 치료방법/Succulent plant disease/多肉植物病虫害
#
# [['desktop.ini', '[초보학습#9] 다육식물 병충해 종류와 원인, 치료방법_Succulent plant disease_多肉植物病虫害 - Korean.srt']]
# /Users/user/Downloads/[초보학습#9] 다육식물 병충해 종류와 원인, 치료방법_Succulent plant disease_多肉植物病虫害 - Korean.srt
# 462
# seed : https://www.youtube.com/watch?v=3zOzlMME_0Y&app=desktop
#
#     [초보학습#8] 다육식물 이상 증상의 원인과 대책/Abnormal Symptoms and Solutions of Succulent Plants/多肉植物
#
# [['desktop.ini', '[초보학습#8] 다육식물 이상 증상의 원인과 대책_Abnormal Symptoms and Solutions of Succulent Plants_多肉植物 - Korean.srt']]
# /Users/user/Downloads/[초보학습#8] 다육식물 이상 증상의 원인과 대책_Abnormal Symptoms and Solutions of Succulent Plants_多肉植物 - Korean.srt
# 463
# seed : https://www.youtube.com/watch?v=NlcxAxGO3Xs&app=desktop
# 464
# seed : https://www.youtube.com/watch?v=OBh-SitvJIc&app=desktop
#
#     다육이 세옥씨네 묶은둥이~^^♡
#
# [['desktop.ini', '다육이 세옥씨네 묶은둥이_^^♡ - Korean (auto-generated).srt']]
# /Users/user/Downloads/다육이 세옥씨네 묶은둥이_^^♡ - Korean (auto-generated).srt
# 465
# seed : https://www.youtube.com/watch?v=YA1bBiBKZis&app=desktop
#
#     저희집에는 물을 많이먹어서 잎장이 터진다육 도 있습니다
#
# [['desktop.ini', '저희집에는 물을 많이먹어서 잎장이 터진다육 도 있습니다 - Korean (auto-generated).srt']]
# /Users/user/Downloads/저희집에는 물을 많이먹어서 잎장이 터진다육 도 있습니다 - Korean (auto-generated).srt
# 466
# seed : https://www.youtube.com/watch?v=x-gaNq-ym6w&app=desktop
# 467
# seed : https://www.youtube.com/watch?v=srsjjIw2fdY&app=desktop
# 468
# seed : https://www.youtube.com/watch?v=fDjsCX2ZLU8&app=desktop
#
#     최연소 여자야구 국대 투수가 사회인야구에 출전하면?
#
# [['desktop.ini', '최연소 여자야구 국대 투수가 사회인야구에 출전하면_ - Korean (auto-generated).srt']]
# /Users/user/Downloads/최연소 여자야구 국대 투수가 사회인야구에 출전하면_ - Korean (auto-generated).srt
# 469
# seed : https://www.youtube.com/watch?v=bd6Zx4svULw&app=desktop
#
#     초등학생이 호날두킥 가능하다고? 김병지 상대로 골넣는 파워초딩ㅋㅋㅋ
#
# [['desktop.ini', '초등학생이 호날두킥 가능하다고_ 김병지 상대로 골넣는 파워초딩ㅋㅋㅋ - Korean (auto-generated).srt']]
# /Users/user/Downloads/초등학생이 호날두킥 가능하다고_ 김병지 상대로 골넣는 파워초딩ㅋㅋㅋ - Korean (auto-generated).srt
# 470
# seed : https://www.youtube.com/watch?v=W6KdDfNOYQE&app=desktop
#
#     대한민국 남여 프리킥 원탑 대결ㅣ프로 프리킥 득점 1위끼리 붙음. 지구특꽁대 10화 특별편
#
# [['desktop.ini', '대한민국 남여 프리킥 원탑 대결ㅣ프로 프리킥 득점 1위끼리 붙음. 지구특꽁대 10화 특별편 - Korean (auto-generated).srt']]
# /Users/user/Downloads/대한민국 남여 프리킥 원탑 대결ㅣ프로 프리킥 득점 1위끼리 붙음. 지구특꽁대 10화 특별편 - Korean (auto-generated).srt
# 471
# seed : https://www.youtube.com/watch?v=Kv_bncEeY0o&app=desktop
#
#     국가대표 김형범이 조기축구 용병뛴날 (클래스는 영원하다ㄷㄷ) | 형컴이 간다 1화
#
# [['desktop.ini', '국가대표 김형범이 조기축구 용병뛴날 (클래스는 영원하다ㄷㄷ) _ 형컴이 간다 1화 - Korean (auto-generated).srt']]
# /Users/user/Downloads/국가대표 김형범이 조기축구 용병뛴날 (클래스는 영원하다ㄷㄷ) _ 형컴이 간다 1화 - Korean (auto-generated).srt
# 472
# seed : https://www.youtube.com/watch?v=ailKxUlaPh0&app=desktop
# 473
# seed : https://www.youtube.com/watch?v=FiwPRg2hUq0&app=desktop
#
#     여자야구올스타 VS 연예인야구팀이 다큐로 붙으면 누가 이기는지 하이라이트
#
# [['desktop.ini', '여자야구올스타 VS 연예인야구팀이 다큐로 붙으면 누가 이기는지 하이라이트 - Korean (auto-generated).srt']]
# /Users/user/Downloads/여자야구올스타 VS 연예인야구팀이 다큐로 붙으면 누가 이기는지 하이라이트 - Korean (auto-generated).srt
# 474
# seed : https://www.youtube.com/watch?v=9TdzsCcWBR8&app=desktop
#
#     칠 테면 쳐봐! 박명환 전력투구 vs 여자 야구선수들 (필살기 슬라이더까지 ㄷㄷㄷ)
#
# [['desktop.ini', '칠 테면 쳐봐! 박명환 전력투구 vs 여자 야구선수들 (필살기 슬라이더까지 ㄷㄷㄷ) - Korean (auto-generated).srt']]
# /Users/user/Downloads/칠 테면 쳐봐! 박명환 전력투구 vs 여자 야구선수들 (필살기 슬라이더까지 ㄷㄷㄷ) - Korean (auto-generated).srt
# 475
# seed : https://www.youtube.com/watch?v=6dmKk1AWbkM&app=desktop
# 476
# seed : https://www.youtube.com/watch?v=Bazm5VONaSA&app=desktop
#
#     4구 당구 모아치기를 하는 12가지 법칙 -아빌309
#
# [['4구 당구 모아치기를 하는 12가지 법칙 -아빌309 - Korean (auto-generated).srt', 'desktop.ini']]
# /Users/user/Downloads/4구 당구 모아치기를 하는 12가지 법칙 -아빌309 - Korean (auto-generated).srt
# 477
# seed : https://www.youtube.com/watch?v=lB9jEW6EGns&app=desktop
#
#     진짜 신기한 고무줄 연결 마술  해법 마술배우기
#
# [['desktop.ini', '진짜 신기한 고무줄 연결 마술 해법 마술배우기 - Korean (auto-generated).srt']]
# /Users/user/Downloads/진짜 신기한 고무줄 연결 마술 해법 마술배우기 - Korean (auto-generated).srt
# 478
# seed : https://www.youtube.com/watch?v=Ld94d_Imopw&app=desktop
#
#     [프로의 한수] 약 빨고 두나...미친척 차로 졸을 치겠습니다. (장기)
#
# [['desktop.ini', '[프로의 한수] 약 빨고 두나...미친척 차로 졸을 치겠습니다. (장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[프로의 한수] 약 빨고 두나...미친척 차로 졸을 치겠습니다. (장기) - Korean (auto-generated).srt
# 479
# seed : https://www.youtube.com/watch?v=0Eoya9hQLuM&app=desktop
#
#     [레전드 명경기] 프로의 패기..깔끔하게 차를 주고 갑시다?? (장기)
#
# [['desktop.ini', '[레전드 명경기] 프로의 패기..깔끔하게 차를 주고 갑시다__ (장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[레전드 명경기] 프로의 패기..깔끔하게 차를 주고 갑시다__ (장기) - Korean (auto-generated).srt
# 480
# seed : https://www.youtube.com/watch?v=gfZhjNoDAdg&app=desktop
#
#     [프로의 한수] 위기를 기회로...회심의 일격??? 꼼수 같은디..(장기)
#
# [['desktop.ini', '[프로의 한수] 위기를 기회로...회심의 일격___ 꼼수 같은디..(장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[프로의 한수] 위기를 기회로...회심의 일격___ 꼼수 같은디..(장기) - Korean (auto-generated).srt
# 481
# seed : https://www.youtube.com/watch?v=0Eoya9hQLuM&app=desktop
# 482
# seed : https://www.youtube.com/watch?v=KfuDVbzGo9c&app=desktop
#
#     [프로의 한수] 한눈 팔면 잡힌다???? 차 잡기 달인 (장기)
#
# [['desktop.ini', '[프로의 한수] 한눈 팔면 잡힌다____ 차 잡기 달인 (장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[프로의 한수] 한눈 팔면 잡힌다____ 차 잡기 달인 (장기) - Korean (auto-generated).srt
# 483
# seed : https://www.youtube.com/watch?v=npXVK_EYMEU&app=desktop
#
#     [프로의 한수] 고급기술 공개...기물을 버리는 요령이 따로 있다???? (장기)
#
# [['desktop.ini', '[프로의 한수] 고급기술 공개...기물을 버리는 요령이 따로 있다____ (장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[프로의 한수] 고급기술 공개...기물을 버리는 요령이 따로 있다____ (장기) - Korean (auto-generated).srt
# 484
# seed : https://www.youtube.com/watch?v=q7xxpq-nSWs&app=desktop
#
#     [중급] 실전장기 - 미쳤어 정말...차를 안잡고 상을 잡는다고????(장기)
#
# [['desktop.ini', '[중급] 실전장기 - 미쳤어 정말...차를 안잡고 상을 잡는다고____(장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[중급] 실전장기 - 미쳤어 정말...차를 안잡고 상을 잡는다고____(장기) - Korean (auto-generated).srt
# 485
# seed : https://www.youtube.com/watch?v=wwfmIksLWAs&app=desktop
#
#     [프로의 뻘수] 프로의 설레발....민망하게 혼자만의 수읽기로 신났네요 ㅠ.ㅠ (장기)
#
# [['desktop.ini', '[프로의 뻘수] 프로의 설레발....민망하게 혼자만의 수읽기로 신났네요 ㅠ.ㅠ (장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[프로의 뻘수] 프로의 설레발....민망하게 혼자만의 수읽기로 신났네요 ㅠ.ㅠ (장기) - Korean (auto-generated).srt
# 486
# seed : https://www.youtube.com/watch?v=ZDLSnZrZWhQ&app=desktop
#
#     [프로의 한수] 개꿀잼 명경기..이래도 장기에 안 반해???(장기)
#
# [['desktop.ini', '[프로의 한수] 개꿀잼 명경기..이래도 장기에 안 반해___(장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[프로의 한수] 개꿀잼 명경기..이래도 장기에 안 반해___(장기) - Korean (auto-generated).srt
# 487
# seed : https://www.youtube.com/watch?v=0Eoya9hQLuM&app=desktop
# 488
# seed : https://www.youtube.com/watch?v=mpDggxulIVg&app=desktop
#
#     [프로의 한수] 양차??? 살릴수 있을 것 같은데...(장기)
#
# [['desktop.ini', '[프로의 한수] 양차___ 살릴수 있을 것 같은데...(장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[프로의 한수] 양차___ 살릴수 있을 것 같은데...(장기) - Korean (auto-generated).srt
# 489
# seed : https://www.youtube.com/watch?v=T3ha30ld4pc&app=desktop
#
#     [프로의 한수] 감금된 차...과연 탈출이 가능할까????(장기)
#
# [['desktop.ini', '[프로의 한수] 감금된 차...과연 탈출이 가능할까____(장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[프로의 한수] 감금된 차...과연 탈출이 가능할까____(장기) - Korean (auto-generated).srt
# 490
# seed : https://www.youtube.com/watch?v=nBgOcx890s8&app=desktop
#
#     [실전 묘수풀이] 실전영상편- 기세가 아주 태풍 뺨따구를...(장기)
#
# [['desktop.ini', '[실전 묘수풀이] 실전영상편- 기세가 아주 태풍 뺨따구를...(장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[실전 묘수풀이] 실전영상편- 기세가 아주 태풍 뺨따구를...(장기) - Korean (auto-generated).srt
# 491
# seed : https://www.youtube.com/watch?v=LGr1Q_yis2o&app=desktop
#
#     [프로의 한수] 고수들의 싸움..장군을 한번도 못부르네...(장기)
#
# [['desktop.ini', '[프로의 한수] 고수들의 싸움..장군을 한번도 못부르네...(장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[프로의 한수] 고수들의 싸움..장군을 한번도 못부르네...(장기) - Korean (auto-generated).srt
# 492
# seed : https://www.youtube.com/watch?v=0Eoya9hQLuM&app=desktop
# 493
# seed : https://www.youtube.com/watch?v=KfuDVbzGo9c&app=desktop
# 494
# seed : https://www.youtube.com/watch?v=DggFpSbfGBI&app=desktop
#
#     [프로의 한수] 미래를 보는 사나이...포로 사를 친다고???? (장기)
#
# [['desktop.ini', '[프로의 한수] 미래를 보는 사나이...포로 사를 친다고____ (장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[프로의 한수] 미래를 보는 사나이...포로 사를 친다고____ (장기) - Korean (auto-generated).srt
# 495
# seed : https://www.youtube.com/watch?v=ysx9gY2MbgE&app=desktop
#
#     [프로의 한수] 두근 두근 심장 움츠러드는 아슬아슬 장기 (장기)
#
# [['desktop.ini', '[프로의 한수] 두근 두근 심장 움츠러드는 아슬아슬 장기 (장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[프로의 한수] 두근 두근 심장 움츠러드는 아슬아슬 장기 (장기) - Korean (auto-generated).srt
# 496
# seed : https://www.youtube.com/watch?v=0Eoya9hQLuM&app=desktop
# 497
# seed : https://www.youtube.com/watch?v=LGr1Q_yis2o&app=desktop
# 498
# seed : https://www.youtube.com/watch?v=bDktSavhsP0&app=desktop
# 499
# seed : https://www.youtube.com/watch?v=6K1lIcnoY2M&app=desktop
#
#     [프로의 한수] 천국과 지옥을 오가는 장기...멘탈붕괴???? (장기)
#
# [['desktop.ini', '[프로의 한수] 천국과 지옥을 오가는 장기...멘탈붕괴____ (장기) - Korean (auto-generated).srt']]
# /Users/user/Downloads/[프로의 한수] 천국과 지옥을 오가는 장기...멘탈붕괴____ (장기) - Korean (auto-generated).srt

# %%
youtube(n = 10, seed = "https://www.youtube.com/watch?v=MHd93E94kQc&app=desktop") # seed : 쌍튜브
# Out:
# 0
# seed : https://www.youtube.com/watch?v=MHd93E94kQc&app=desktop
# 1
# seed : https://www.youtube.com/watch?v=59lib73KEiE&app=desktop
#
#     쌍튜브] 쌍베의 특수능력 '조륜안' - 카트라이더
#
# [['desktop.ini', "쌍튜브] 쌍베의 특수능력 '조륜안' - 카트라이더 - Korean (auto-generated).srt"]]
# /Users/user/Downloads/쌍튜브] 쌍베의 특수능력 '조륜안' - 카트라이더 - Korean (auto-generated).srt
# 2
# seed : https://www.youtube.com/watch?v=Nz5UUWA1pMg&app=desktop
#
#     쌍튜브] 블리자드가 쌍베에게 독을 탓다.. - 카트라이더
#
# [['desktop.ini', '쌍튜브] 블리자드가 쌍베에게 독을 탓다.. - 카트라이더 - Korean (auto-generated).srt']]
# /Users/user/Downloads/쌍튜브] 블리자드가 쌍베에게 독을 탓다.. - 카트라이더 - Korean (auto-generated).srt
# 3
# seed : https://www.youtube.com/watch?v=uz3hYOKwoSo&app=desktop
# 4
# seed : https://www.youtube.com/watch?v=N8PAmFrfSuo&app=desktop
#
#     할로윈 인 더 와나나(견자희,형독)
#
# [['desktop.ini', '할로윈 인 더 와나나(견자희,형독) - Korean (auto-generated).srt']]
# /Users/user/Downloads/할로윈 인 더 와나나(견자희,형독) - Korean (auto-generated).srt
# 5
# seed : https://www.youtube.com/watch?v=EcyanqiEMUc&app=desktop
#
#     탬탬버린님 인성 폭로(with 김진우님)
#
# [['desktop.ini', '탬탬버린님 인성 폭로(with 김진우님) - Korean (auto-generated).srt']]
# /Users/user/Downloads/탬탬버린님 인성 폭로(with 김진우님) - Korean (auto-generated).srt
# 6
# seed : https://www.youtube.com/watch?v=JCJNx0nDQBU&app=desktop
#
#     와나나야 머리숱은 없어도 여자 친구는 있어야지
#
# [['desktop.ini', '와나나야 머리숱은 없어도 여자 친구는 있어야지 - Korean (auto-generated).srt']]
# /Users/user/Downloads/와나나야 머리숱은 없어도 여자 친구는 있어야지 - Korean (auto-generated).srt
# 7
# seed : https://www.youtube.com/watch?v=CybVYYxYOps&app=desktop
#
#     혼자 스키장 간 썰..
#
# [['desktop.ini', '혼자 스키장 간 썰.. - Korean (auto-generated).srt']]
# /Users/user/Downloads/혼자 스키장 간 썰.. - Korean (auto-generated).srt
# 8
# seed : https://www.youtube.com/watch?v=JQISDk--N2E&app=desktop
#
#     크리스마스에도 일하는 가엾은 웹툰 작가 레바 ㅠㅠ
#
# [['desktop.ini', '크리스마스에도 일하는 가엾은 웹툰 작가 레바 ㅠㅠ - Korean (auto-generated).srt']]
# /Users/user/Downloads/크리스마스에도 일하는 가엾은 웹툰 작가 레바 ㅠㅠ - Korean (auto-generated).srt
# 9
# seed : https://www.youtube.com/watch?v=BYUMIhcFUT4&app=desktop
#
#     고해성사 본편 시작.. 이것들도 인간입니까?;;
#
# [['desktop.ini', '고해성사 본편 시작.. 이것들도 인간입니까_;; - Korean (auto-generated).srt']]
# /Users/user/Downloads/고해성사 본편 시작.. 이것들도 인간입니까_;; - Korean (auto-generated).srt

# %%
con.close()
